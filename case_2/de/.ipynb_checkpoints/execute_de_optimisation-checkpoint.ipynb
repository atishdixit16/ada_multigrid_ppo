# %%
# to access functions from root directory 
import sys
sys.path.append('/data/ad181/RemoteDir/rl_robust_owc')

# %%
# %matplotlib notebook
from utils.plot_functions import plot_s_animation, plot_s_snapshots

import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.optimize import differential_evolution

from utils.env_evaluate_functions import eval_actions
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case = 'case_1'
opt_dir = './'+case
os.makedirs(opt_dir, exist_ok=True)

# %%
with open('../envs_params/env_data/env_list_eval.pkl', 'rb') as input:
    envs = pickle.load(input)
rl_indices = list(range(16))

# %%
def objective_function(q_arg, *args ):
    env = args[0]
    assert q_arg.size == env.terminal_step*env.action_space.shape[0], 'invalid argument size'
    q_arg = q_arg.reshape(env.terminal_step, -1)
    _,_, rewards = eval_actions(env, q_arg)
    return -sum(rewards)

# %%
for i,env in enumerate(envs):
    if i in rl_indices:
        args = (env,)
        base_action = np.ones((env.terminal_step,env.action_space.shape[0]))
        _,_, rewards = eval_actions(env, base_action)
        print(f'case: {i} (base reward: {-round(sum(rewards), 2)})')
        bounds =  [(env.action_space.low[0],env.action_space.high[0])]*(env.terminal_step*env.action_space.shape[0])
        result = differential_evolution(objective_function, bounds, args=args,
                                    maxiter=750, popsize=1, tol=1e-5,
                                    disp=True, polish=False,
                                    recombination=0.9, mutation=(0.5,1),
                                    updating='deferred', workers=64, seed=seed)
        np.save(opt_dir+'/ck_argmax_'+str(i)+'.npy', result.x)
        np.save(opt_dir+'/ck_max_'+str(i)+'.npy', result.fun)
        print(result.fun, result.x)
# Out:
# case: 0 (base reward: -0.6)
# differential_evolution step 1: f(x)= -0.632962
# differential_evolution step 2: f(x)= -0.641028
# differential_evolution step 3: f(x)= -0.641028
# differential_evolution step 4: f(x)= -0.644114
# differential_evolution step 5: f(x)= -0.644114
# differential_evolution step 6: f(x)= -0.645791
# differential_evolution step 7: f(x)= -0.645791
# differential_evolution step 8: f(x)= -0.645791
# differential_evolution step 9: f(x)= -0.645791
# differential_evolution step 10: f(x)= -0.645791
# differential_evolution step 11: f(x)= -0.645791
# differential_evolution step 12: f(x)= -0.645791
# differential_evolution step 13: f(x)= -0.645791
# differential_evolution step 14: f(x)= -0.645809
# differential_evolution step 15: f(x)= -0.645809
# differential_evolution step 16: f(x)= -0.645809
# differential_evolution step 17: f(x)= -0.645809
# differential_evolution step 18: f(x)= -0.647393
# differential_evolution step 19: f(x)= -0.648582
# differential_evolution step 20: f(x)= -0.648582
# differential_evolution step 21: f(x)= -0.650768
# differential_evolution step 22: f(x)= -0.650768
# differential_evolution step 23: f(x)= -0.650768
# differential_evolution step 24: f(x)= -0.650768
# differential_evolution step 25: f(x)= -0.650768
# differential_evolution step 26: f(x)= -0.651218
# differential_evolution step 27: f(x)= -0.654249
# differential_evolution step 28: f(x)= -0.654249
# differential_evolution step 29: f(x)= -0.654249
# differential_evolution step 30: f(x)= -0.654249
# differential_evolution step 31: f(x)= -0.656972
# differential_evolution step 32: f(x)= -0.657891
# differential_evolution step 33: f(x)= -0.659
# differential_evolution step 34: f(x)= -0.659
# differential_evolution step 35: f(x)= -0.659
# differential_evolution step 36: f(x)= -0.659
# differential_evolution step 37: f(x)= -0.659
# differential_evolution step 38: f(x)= -0.659
# differential_evolution step 39: f(x)= -0.659
# differential_evolution step 40: f(x)= -0.659
# differential_evolution step 41: f(x)= -0.659
# differential_evolution step 42: f(x)= -0.659
# differential_evolution step 43: f(x)= -0.659
# differential_evolution step 44: f(x)= -0.659
# differential_evolution step 45: f(x)= -0.659
# differential_evolution step 46: f(x)= -0.659
# differential_evolution step 47: f(x)= -0.660327
# differential_evolution step 48: f(x)= -0.660327
# differential_evolution step 49: f(x)= -0.660327
# differential_evolution step 50: f(x)= -0.660327
# differential_evolution step 51: f(x)= -0.660327
# differential_evolution step 52: f(x)= -0.660327
# differential_evolution step 53: f(x)= -0.660327
# differential_evolution step 54: f(x)= -0.660327
# differential_evolution step 55: f(x)= -0.660327
# differential_evolution step 56: f(x)= -0.660327
# differential_evolution step 57: f(x)= -0.660327
# differential_evolution step 58: f(x)= -0.660327
# differential_evolution step 59: f(x)= -0.660408
# differential_evolution step 60: f(x)= -0.660408
# differential_evolution step 61: f(x)= -0.660408
# differential_evolution step 62: f(x)= -0.660408
# differential_evolution step 63: f(x)= -0.660408
# differential_evolution step 64: f(x)= -0.660408
# differential_evolution step 65: f(x)= -0.660408
# differential_evolution step 66: f(x)= -0.660408
# differential_evolution step 67: f(x)= -0.660408
# differential_evolution step 68: f(x)= -0.660408
# differential_evolution step 69: f(x)= -0.662107
# differential_evolution step 70: f(x)= -0.662736
# differential_evolution step 71: f(x)= -0.662736
# differential_evolution step 72: f(x)= -0.662741
# differential_evolution step 73: f(x)= -0.662741
# differential_evolution step 74: f(x)= -0.662741
# differential_evolution step 75: f(x)= -0.664273
# differential_evolution step 76: f(x)= -0.664273
# differential_evolution step 77: f(x)= -0.664273
# differential_evolution step 78: f(x)= -0.66702
# differential_evolution step 79: f(x)= -0.66702
# differential_evolution step 80: f(x)= -0.66702
# differential_evolution step 81: f(x)= -0.66702
# differential_evolution step 82: f(x)= -0.66702
# differential_evolution step 83: f(x)= -0.66702
# differential_evolution step 84: f(x)= -0.66702
# differential_evolution step 85: f(x)= -0.66822
# differential_evolution step 86: f(x)= -0.66822
# differential_evolution step 87: f(x)= -0.66822
# differential_evolution step 88: f(x)= -0.66822
# differential_evolution step 89: f(x)= -0.66822
# differential_evolution step 90: f(x)= -0.66822
# differential_evolution step 91: f(x)= -0.66822
# differential_evolution step 92: f(x)= -0.66822
# differential_evolution step 93: f(x)= -0.66822
# differential_evolution step 94: f(x)= -0.66822
# differential_evolution step 95: f(x)= -0.66822
# differential_evolution step 96: f(x)= -0.66822
# differential_evolution step 97: f(x)= -0.66822
# differential_evolution step 98: f(x)= -0.66822
# differential_evolution step 99: f(x)= -0.66822
# differential_evolution step 100: f(x)= -0.66822
# differential_evolution step 101: f(x)= -0.66822
# differential_evolution step 102: f(x)= -0.66822
# differential_evolution step 103: f(x)= -0.66822
# differential_evolution step 104: f(x)= -0.66822
# differential_evolution step 105: f(x)= -0.66822
# differential_evolution step 106: f(x)= -0.66822
# differential_evolution step 107: f(x)= -0.66822
# differential_evolution step 108: f(x)= -0.66822
# differential_evolution step 109: f(x)= -0.66822
# differential_evolution step 110: f(x)= -0.66822
# differential_evolution step 111: f(x)= -0.66822
# differential_evolution step 112: f(x)= -0.66822
# differential_evolution step 113: f(x)= -0.66822
# differential_evolution step 114: f(x)= -0.66822
# differential_evolution step 115: f(x)= -0.66822
# differential_evolution step 116: f(x)= -0.66822
# differential_evolution step 117: f(x)= -0.66822
# differential_evolution step 118: f(x)= -0.66822
# differential_evolution step 119: f(x)= -0.66822
# differential_evolution step 120: f(x)= -0.66822
# differential_evolution step 121: f(x)= -0.66822
# differential_evolution step 122: f(x)= -0.66822
# differential_evolution step 123: f(x)= -0.66822
# differential_evolution step 124: f(x)= -0.66822
# differential_evolution step 125: f(x)= -0.66822
# differential_evolution step 126: f(x)= -0.66822
# differential_evolution step 127: f(x)= -0.66822
# differential_evolution step 128: f(x)= -0.66822
# differential_evolution step 129: f(x)= -0.66822
# differential_evolution step 130: f(x)= -0.66822
# differential_evolution step 131: f(x)= -0.66822
# differential_evolution step 132: f(x)= -0.669136
# differential_evolution step 133: f(x)= -0.669136
# differential_evolution step 134: f(x)= -0.669136
# differential_evolution step 135: f(x)= -0.669136
# differential_evolution step 136: f(x)= -0.669136
# differential_evolution step 137: f(x)= -0.669136
# differential_evolution step 138: f(x)= -0.669136
# differential_evolution step 139: f(x)= -0.669136
# differential_evolution step 140: f(x)= -0.669136
# differential_evolution step 141: f(x)= -0.669136
# differential_evolution step 142: f(x)= -0.669136
# differential_evolution step 143: f(x)= -0.669136
# differential_evolution step 144: f(x)= -0.669136
# differential_evolution step 145: f(x)= -0.669136
# differential_evolution step 146: f(x)= -0.669136
# differential_evolution step 147: f(x)= -0.669136
# differential_evolution step 148: f(x)= -0.669136
# differential_evolution step 149: f(x)= -0.669136
# differential_evolution step 150: f(x)= -0.669136
# differential_evolution step 151: f(x)= -0.669136
# differential_evolution step 152: f(x)= -0.669136
# differential_evolution step 153: f(x)= -0.669136
# differential_evolution step 154: f(x)= -0.669136
# differential_evolution step 155: f(x)= -0.671085
# differential_evolution step 156: f(x)= -0.671085
# differential_evolution step 157: f(x)= -0.671085
# differential_evolution step 158: f(x)= -0.671085
# differential_evolution step 159: f(x)= -0.671085
# differential_evolution step 160: f(x)= -0.671085
# differential_evolution step 161: f(x)= -0.671085
# differential_evolution step 162: f(x)= -0.671085
# differential_evolution step 163: f(x)= -0.671085
# differential_evolution step 164: f(x)= -0.671085
# differential_evolution step 165: f(x)= -0.671085
# differential_evolution step 166: f(x)= -0.671085
# differential_evolution step 167: f(x)= -0.671085
# differential_evolution step 168: f(x)= -0.671085
# differential_evolution step 169: f(x)= -0.671085
# differential_evolution step 170: f(x)= -0.671085
# differential_evolution step 171: f(x)= -0.671085
# differential_evolution step 172: f(x)= -0.671085
# differential_evolution step 173: f(x)= -0.671085
# differential_evolution step 174: f(x)= -0.671085
# differential_evolution step 175: f(x)= -0.671085
# differential_evolution step 176: f(x)= -0.6725
# differential_evolution step 177: f(x)= -0.6725
# differential_evolution step 178: f(x)= -0.6725
# differential_evolution step 179: f(x)= -0.6725
# differential_evolution step 180: f(x)= -0.6725
# differential_evolution step 181: f(x)= -0.6725
# differential_evolution step 182: f(x)= -0.672949
# differential_evolution step 183: f(x)= -0.672949
# differential_evolution step 184: f(x)= -0.672949
# differential_evolution step 185: f(x)= -0.672949
# differential_evolution step 186: f(x)= -0.672949
# differential_evolution step 187: f(x)= -0.672949
# differential_evolution step 188: f(x)= -0.673807
# differential_evolution step 189: f(x)= -0.673807
# differential_evolution step 190: f(x)= -0.673807
# differential_evolution step 191: f(x)= -0.674442
# differential_evolution step 192: f(x)= -0.674442
# differential_evolution step 193: f(x)= -0.674442
# differential_evolution step 194: f(x)= -0.674442
# differential_evolution step 195: f(x)= -0.674442
# differential_evolution step 196: f(x)= -0.674442
# differential_evolution step 197: f(x)= -0.674442
# differential_evolution step 198: f(x)= -0.674442
# differential_evolution step 199: f(x)= -0.674597
# differential_evolution step 200: f(x)= -0.675869
# differential_evolution step 201: f(x)= -0.675869
# differential_evolution step 202: f(x)= -0.675869
# differential_evolution step 203: f(x)= -0.675869
# differential_evolution step 204: f(x)= -0.676381
# differential_evolution step 205: f(x)= -0.676381
# differential_evolution step 206: f(x)= -0.676381
# differential_evolution step 207: f(x)= -0.676381
# differential_evolution step 208: f(x)= -0.676381
# differential_evolution step 209: f(x)= -0.676381
# differential_evolution step 210: f(x)= -0.676381
# differential_evolution step 211: f(x)= -0.676381
# differential_evolution step 212: f(x)= -0.676483
# differential_evolution step 213: f(x)= -0.676483
# differential_evolution step 214: f(x)= -0.676483
# differential_evolution step 215: f(x)= -0.676483
# differential_evolution step 216: f(x)= -0.676857
# differential_evolution step 217: f(x)= -0.676857
# differential_evolution step 218: f(x)= -0.676857
# differential_evolution step 219: f(x)= -0.676857
# differential_evolution step 220: f(x)= -0.676857
# differential_evolution step 221: f(x)= -0.676857
# differential_evolution step 222: f(x)= -0.676857
# differential_evolution step 223: f(x)= -0.677258
# differential_evolution step 224: f(x)= -0.677258
# differential_evolution step 225: f(x)= -0.677258
# differential_evolution step 226: f(x)= -0.67982
# differential_evolution step 227: f(x)= -0.67982
# differential_evolution step 228: f(x)= -0.67982
# differential_evolution step 229: f(x)= -0.67982
# differential_evolution step 230: f(x)= -0.67982
# differential_evolution step 231: f(x)= -0.67982
# differential_evolution step 232: f(x)= -0.68007
# differential_evolution step 233: f(x)= -0.680246
# differential_evolution step 234: f(x)= -0.680777
# differential_evolution step 235: f(x)= -0.680777
# differential_evolution step 236: f(x)= -0.680777
# differential_evolution step 237: f(x)= -0.681374
# differential_evolution step 238: f(x)= -0.681547
# differential_evolution step 239: f(x)= -0.681547
# differential_evolution step 240: f(x)= -0.681587
# differential_evolution step 241: f(x)= -0.681587
# differential_evolution step 242: f(x)= -0.681587
# differential_evolution step 243: f(x)= -0.681587
# differential_evolution step 244: f(x)= -0.681587
# differential_evolution step 245: f(x)= -0.681587
# differential_evolution step 246: f(x)= -0.681587
# differential_evolution step 247: f(x)= -0.682413
# differential_evolution step 248: f(x)= -0.682413
# differential_evolution step 249: f(x)= -0.682413
# differential_evolution step 250: f(x)= -0.682413
# differential_evolution step 251: f(x)= -0.682413
# differential_evolution step 252: f(x)= -0.682413
# differential_evolution step 253: f(x)= -0.682413
# differential_evolution step 254: f(x)= -0.682413
# differential_evolution step 255: f(x)= -0.682413
# differential_evolution step 256: f(x)= -0.682413
# differential_evolution step 257: f(x)= -0.682413
# differential_evolution step 258: f(x)= -0.682413
# differential_evolution step 259: f(x)= -0.682413
# differential_evolution step 260: f(x)= -0.682413
# differential_evolution step 261: f(x)= -0.682413
# differential_evolution step 262: f(x)= -0.682413
# differential_evolution step 263: f(x)= -0.682413
# differential_evolution step 264: f(x)= -0.682911
# differential_evolution step 265: f(x)= -0.682911
# differential_evolution step 266: f(x)= -0.682911
# differential_evolution step 267: f(x)= -0.682911
# differential_evolution step 268: f(x)= -0.682911
# differential_evolution step 269: f(x)= -0.682911
# differential_evolution step 270: f(x)= -0.682911
# differential_evolution step 271: f(x)= -0.682911
# differential_evolution step 272: f(x)= -0.682911
# differential_evolution step 273: f(x)= -0.682911
# differential_evolution step 274: f(x)= -0.682911
# differential_evolution step 275: f(x)= -0.682911
# differential_evolution step 276: f(x)= -0.682911
# differential_evolution step 277: f(x)= -0.682911
# differential_evolution step 278: f(x)= -0.682911
# differential_evolution step 279: f(x)= -0.682911
# differential_evolution step 280: f(x)= -0.682911
# differential_evolution step 281: f(x)= -0.682911
# differential_evolution step 282: f(x)= -0.682911
# differential_evolution step 283: f(x)= -0.682911
# differential_evolution step 284: f(x)= -0.684198
# differential_evolution step 285: f(x)= -0.686024
# differential_evolution step 286: f(x)= -0.686024
# differential_evolution step 287: f(x)= -0.686024
# differential_evolution step 288: f(x)= -0.686024
# differential_evolution step 289: f(x)= -0.686024
# differential_evolution step 290: f(x)= -0.686024
# differential_evolution step 291: f(x)= -0.686024
# differential_evolution step 292: f(x)= -0.686024
# differential_evolution step 293: f(x)= -0.686024
# differential_evolution step 294: f(x)= -0.686024
# differential_evolution step 295: f(x)= -0.686024
# differential_evolution step 296: f(x)= -0.686534
# differential_evolution step 297: f(x)= -0.687714
# differential_evolution step 298: f(x)= -0.687714
# differential_evolution step 299: f(x)= -0.687714
# differential_evolution step 300: f(x)= -0.687714
# differential_evolution step 301: f(x)= -0.687714
# differential_evolution step 302: f(x)= -0.687714
# differential_evolution step 303: f(x)= -0.688079
# differential_evolution step 304: f(x)= -0.688153
# differential_evolution step 305: f(x)= -0.688153
# differential_evolution step 306: f(x)= -0.688153
# differential_evolution step 307: f(x)= -0.688153
# differential_evolution step 308: f(x)= -0.688236
# differential_evolution step 309: f(x)= -0.688236
# differential_evolution step 310: f(x)= -0.688236
# differential_evolution step 311: f(x)= -0.688236
# differential_evolution step 312: f(x)= -0.688716
# differential_evolution step 313: f(x)= -0.688716
# differential_evolution step 314: f(x)= -0.688716
# differential_evolution step 315: f(x)= -0.688716
# differential_evolution step 316: f(x)= -0.688716
# differential_evolution step 317: f(x)= -0.688716
# differential_evolution step 318: f(x)= -0.688786
# differential_evolution step 319: f(x)= -0.689328
# differential_evolution step 320: f(x)= -0.689328
# differential_evolution step 321: f(x)= -0.689328
# differential_evolution step 322: f(x)= -0.689328
# differential_evolution step 323: f(x)= -0.689328
# differential_evolution step 324: f(x)= -0.689538
# differential_evolution step 325: f(x)= -0.690054
# differential_evolution step 326: f(x)= -0.690054
# differential_evolution step 327: f(x)= -0.690128
# differential_evolution step 328: f(x)= -0.690894
# differential_evolution step 329: f(x)= -0.690894
# differential_evolution step 330: f(x)= -0.690894
# differential_evolution step 331: f(x)= -0.690894
# differential_evolution step 332: f(x)= -0.690894
# differential_evolution step 333: f(x)= -0.690894
# differential_evolution step 334: f(x)= -0.690894
# differential_evolution step 335: f(x)= -0.690894
# differential_evolution step 336: f(x)= -0.690894
# differential_evolution step 337: f(x)= -0.690894
# differential_evolution step 338: f(x)= -0.690894
# differential_evolution step 339: f(x)= -0.690894
# differential_evolution step 340: f(x)= -0.690894
# differential_evolution step 341: f(x)= -0.690894
# differential_evolution step 342: f(x)= -0.690894
# differential_evolution step 343: f(x)= -0.690894
# differential_evolution step 344: f(x)= -0.690894
# differential_evolution step 345: f(x)= -0.690894
# differential_evolution step 346: f(x)= -0.691214
# differential_evolution step 347: f(x)= -0.691214
# differential_evolution step 348: f(x)= -0.691214
# differential_evolution step 349: f(x)= -0.691284
# differential_evolution step 350: f(x)= -0.691284
# differential_evolution step 351: f(x)= -0.691284
# differential_evolution step 352: f(x)= -0.691483
# differential_evolution step 353: f(x)= -0.691483
# differential_evolution step 354: f(x)= -0.691483
# differential_evolution step 355: f(x)= -0.691483
# differential_evolution step 356: f(x)= -0.691483
# differential_evolution step 357: f(x)= -0.691483
# differential_evolution step 358: f(x)= -0.691483
# differential_evolution step 359: f(x)= -0.691483
# differential_evolution step 360: f(x)= -0.691952
# differential_evolution step 361: f(x)= -0.691952
# differential_evolution step 362: f(x)= -0.691952
# differential_evolution step 363: f(x)= -0.691952
# differential_evolution step 364: f(x)= -0.691952
# differential_evolution step 365: f(x)= -0.691952
# differential_evolution step 366: f(x)= -0.691952
# differential_evolution step 367: f(x)= -0.691952
# differential_evolution step 368: f(x)= -0.692065
# differential_evolution step 369: f(x)= -0.692065
# differential_evolution step 370: f(x)= -0.692351
# differential_evolution step 371: f(x)= -0.692351
# differential_evolution step 372: f(x)= -0.692351
# differential_evolution step 373: f(x)= -0.692351
# differential_evolution step 374: f(x)= -0.692351
# differential_evolution step 375: f(x)= -0.692412
# differential_evolution step 376: f(x)= -0.692412
# differential_evolution step 377: f(x)= -0.692412
# differential_evolution step 378: f(x)= -0.692412
# differential_evolution step 379: f(x)= -0.692412
# differential_evolution step 380: f(x)= -0.692412
# differential_evolution step 381: f(x)= -0.692412
# differential_evolution step 382: f(x)= -0.692412
# differential_evolution step 383: f(x)= -0.692412
# differential_evolution step 384: f(x)= -0.692412
# differential_evolution step 385: f(x)= -0.692412
# differential_evolution step 386: f(x)= -0.692412
# differential_evolution step 387: f(x)= -0.692412
# differential_evolution step 388: f(x)= -0.692412
# differential_evolution step 389: f(x)= -0.692412
# differential_evolution step 390: f(x)= -0.692412
# differential_evolution step 391: f(x)= -0.692412
# differential_evolution step 392: f(x)= -0.692412
# differential_evolution step 393: f(x)= -0.692412
# differential_evolution step 394: f(x)= -0.692412
# differential_evolution step 395: f(x)= -0.692412
# differential_evolution step 396: f(x)= -0.692412
# differential_evolution step 397: f(x)= -0.692412
# differential_evolution step 398: f(x)= -0.692412
# differential_evolution step 399: f(x)= -0.692412
# differential_evolution step 400: f(x)= -0.692412
# differential_evolution step 401: f(x)= -0.692412
# differential_evolution step 402: f(x)= -0.693441
# differential_evolution step 403: f(x)= -0.693441
# differential_evolution step 404: f(x)= -0.693441
# differential_evolution step 405: f(x)= -0.69395
# differential_evolution step 406: f(x)= -0.69395
# differential_evolution step 407: f(x)= -0.69395
# differential_evolution step 408: f(x)= -0.69395
# differential_evolution step 409: f(x)= -0.69395
# differential_evolution step 410: f(x)= -0.69395
# differential_evolution step 411: f(x)= -0.69395
# differential_evolution step 412: f(x)= -0.69395
# differential_evolution step 413: f(x)= -0.694289
# differential_evolution step 414: f(x)= -0.695831
# differential_evolution step 415: f(x)= -0.695831
# differential_evolution step 416: f(x)= -0.695831
# differential_evolution step 417: f(x)= -0.695831
# differential_evolution step 418: f(x)= -0.695831
# differential_evolution step 419: f(x)= -0.695831
# differential_evolution step 420: f(x)= -0.695831
# differential_evolution step 421: f(x)= -0.695831
# differential_evolution step 422: f(x)= -0.695831
# differential_evolution step 423: f(x)= -0.695831
# differential_evolution step 424: f(x)= -0.695831
# differential_evolution step 425: f(x)= -0.695831
# differential_evolution step 426: f(x)= -0.695848
# differential_evolution step 427: f(x)= -0.695848
# differential_evolution step 428: f(x)= -0.695848
# differential_evolution step 429: f(x)= -0.695848
# differential_evolution step 430: f(x)= -0.695848
# differential_evolution step 431: f(x)= -0.695848
# differential_evolution step 432: f(x)= -0.695848
# differential_evolution step 433: f(x)= -0.695848
# differential_evolution step 434: f(x)= -0.695848
# differential_evolution step 435: f(x)= -0.696345
# differential_evolution step 436: f(x)= -0.696345
# differential_evolution step 437: f(x)= -0.696437
# differential_evolution step 438: f(x)= -0.696437
# differential_evolution step 439: f(x)= -0.696935
# differential_evolution step 440: f(x)= -0.696935
# differential_evolution step 441: f(x)= -0.696935
# differential_evolution step 442: f(x)= -0.696935
# differential_evolution step 443: f(x)= -0.696935
# differential_evolution step 444: f(x)= -0.696935
# differential_evolution step 445: f(x)= -0.696935
# differential_evolution step 446: f(x)= -0.696935
# differential_evolution step 447: f(x)= -0.696935
# differential_evolution step 448: f(x)= -0.696935
# differential_evolution step 449: f(x)= -0.696935
# differential_evolution step 450: f(x)= -0.696935
# differential_evolution step 451: f(x)= -0.696935
# differential_evolution step 452: f(x)= -0.696935
# differential_evolution step 453: f(x)= -0.696935
# differential_evolution step 454: f(x)= -0.696935
# differential_evolution step 455: f(x)= -0.696935
# differential_evolution step 456: f(x)= -0.696935
# differential_evolution step 457: f(x)= -0.696935
# differential_evolution step 458: f(x)= -0.696935
# differential_evolution step 459: f(x)= -0.696935
# differential_evolution step 460: f(x)= -0.696935
# differential_evolution step 461: f(x)= -0.696935
# differential_evolution step 462: f(x)= -0.696935
# differential_evolution step 463: f(x)= -0.696935
# differential_evolution step 464: f(x)= -0.696935
# differential_evolution step 465: f(x)= -0.696935
# differential_evolution step 466: f(x)= -0.696935
# differential_evolution step 467: f(x)= -0.696935
# differential_evolution step 468: f(x)= -0.696935
# differential_evolution step 469: f(x)= -0.696935
# differential_evolution step 470: f(x)= -0.696935
# differential_evolution step 471: f(x)= -0.696935
# differential_evolution step 472: f(x)= -0.697539
# differential_evolution step 473: f(x)= -0.697539
# differential_evolution step 474: f(x)= -0.697539
# differential_evolution step 475: f(x)= -0.697539
# differential_evolution step 476: f(x)= -0.697539
# differential_evolution step 477: f(x)= -0.697539
# differential_evolution step 478: f(x)= -0.697539
# differential_evolution step 479: f(x)= -0.697539
# differential_evolution step 480: f(x)= -0.697539
# differential_evolution step 481: f(x)= -0.697539
# differential_evolution step 482: f(x)= -0.697539
# differential_evolution step 483: f(x)= -0.697539
# differential_evolution step 484: f(x)= -0.697539
# differential_evolution step 485: f(x)= -0.697539
# differential_evolution step 486: f(x)= -0.697539
# differential_evolution step 487: f(x)= -0.697539
# differential_evolution step 488: f(x)= -0.697539
# differential_evolution step 489: f(x)= -0.697539
# differential_evolution step 490: f(x)= -0.697539
# differential_evolution step 491: f(x)= -0.697539
# differential_evolution step 492: f(x)= -0.697539
# differential_evolution step 493: f(x)= -0.697539
# differential_evolution step 494: f(x)= -0.697539
# differential_evolution step 495: f(x)= -0.697539
# differential_evolution step 497: f(x)= -0.697539
# differential_evolution step 498: f(x)= -0.698011
# differential_evolution step 499: f(x)= -0.698046
# differential_evolution step 500: f(x)= -0.698628
# differential_evolution step 501: f(x)= -0.698628
# differential_evolution step 502: f(x)= -0.698628
# differential_evolution step 503: f(x)= -0.698746
# differential_evolution step 504: f(x)= -0.699065
# differential_evolution step 505: f(x)= -0.699065
# differential_evolution step 506: f(x)= -0.699372
# differential_evolution step 507: f(x)= -0.699663
# differential_evolution step 508: f(x)= -0.699663
# differential_evolution step 509: f(x)= -0.699663
# differential_evolution step 510: f(x)= -0.699663
# differential_evolution step 511: f(x)= -0.699663
# differential_evolution step 512: f(x)= -0.699663
# differential_evolution step 513: f(x)= -0.699663
# differential_evolution step 514: f(x)= -0.699663
# differential_evolution step 515: f(x)= -0.699663
# differential_evolution step 516: f(x)= -0.699773
# differential_evolution step 517: f(x)= -0.700122
# differential_evolution step 518: f(x)= -0.700122
# differential_evolution step 519: f(x)= -0.700517
# differential_evolution step 520: f(x)= -0.700701
# differential_evolution step 521: f(x)= -0.700701
# differential_evolution step 522: f(x)= -0.700701
# differential_evolution step 523: f(x)= -0.700701
# differential_evolution step 524: f(x)= -0.700701
# differential_evolution step 525: f(x)= -0.700701
# differential_evolution step 526: f(x)= -0.700701
# differential_evolution step 527: f(x)= -0.700701
# differential_evolution step 528: f(x)= -0.700701
# differential_evolution step 529: f(x)= -0.700701
# differential_evolution step 530: f(x)= -0.700701
# differential_evolution step 531: f(x)= -0.700701
# differential_evolution step 532: f(x)= -0.700701
# differential_evolution step 533: f(x)= -0.700701
# differential_evolution step 534: f(x)= -0.700701
# differential_evolution step 535: f(x)= -0.700701
# differential_evolution step 536: f(x)= -0.700966
# differential_evolution step 537: f(x)= -0.701064
# differential_evolution step 538: f(x)= -0.701064
# differential_evolution step 539: f(x)= -0.701064
# differential_evolution step 540: f(x)= -0.701224
# differential_evolution step 541: f(x)= -0.701224
# differential_evolution step 542: f(x)= -0.701224
# differential_evolution step 543: f(x)= -0.701224
# differential_evolution step 544: f(x)= -0.701224
# differential_evolution step 545: f(x)= -0.701224
# differential_evolution step 546: f(x)= -0.70129
# differential_evolution step 547: f(x)= -0.70129
# differential_evolution step 548: f(x)= -0.70129
# differential_evolution step 549: f(x)= -0.70129
# differential_evolution step 550: f(x)= -0.70129
# differential_evolution step 551: f(x)= -0.70129
# differential_evolution step 552: f(x)= -0.70129
# differential_evolution step 553: f(x)= -0.70129
# differential_evolution step 554: f(x)= -0.701312
# differential_evolution step 555: f(x)= -0.701333
# differential_evolution step 556: f(x)= -0.701333
# differential_evolution step 557: f(x)= -0.701333
# differential_evolution step 558: f(x)= -0.701333
# differential_evolution step 559: f(x)= -0.701333
# differential_evolution step 560: f(x)= -0.701333
# differential_evolution step 561: f(x)= -0.701333
# differential_evolution step 562: f(x)= -0.701678
# differential_evolution step 563: f(x)= -0.701678
# differential_evolution step 564: f(x)= -0.701678
# differential_evolution step 565: f(x)= -0.701678
# differential_evolution step 566: f(x)= -0.701678
# differential_evolution step 567: f(x)= -0.701678
# differential_evolution step 568: f(x)= -0.701678
# differential_evolution step 569: f(x)= -0.701678
# differential_evolution step 570: f(x)= -0.701678
# differential_evolution step 571: f(x)= -0.701678
# differential_evolution step 572: f(x)= -0.701678
# differential_evolution step 573: f(x)= -0.701678
# differential_evolution step 574: f(x)= -0.701678
# differential_evolution step 575: f(x)= -0.701678
# differential_evolution step 576: f(x)= -0.701678
# differential_evolution step 577: f(x)= -0.701678
# differential_evolution step 579: f(x)= -0.701678
# differential_evolution step 580: f(x)= -0.701678
# differential_evolution step 581: f(x)= -0.701678
# differential_evolution step 582: f(x)= -0.701889
# differential_evolution step 583: f(x)= -0.701889
# differential_evolution step 584: f(x)= -0.701889
# differential_evolution step 585: f(x)= -0.701889
# differential_evolution step 586: f(x)= -0.701889
# differential_evolution step 587: f(x)= -0.701932
# differential_evolution step 588: f(x)= -0.701949
# differential_evolution step 589: f(x)= -0.701949
# differential_evolution step 590: f(x)= -0.701949
# differential_evolution step 591: f(x)= -0.702141
# differential_evolution step 592: f(x)= -0.702894
# differential_evolution step 593: f(x)= -0.703008
# differential_evolution step 594: f(x)= -0.703008
# differential_evolution step 595: f(x)= -0.703008
# differential_evolution step 596: f(x)= -0.703008
# differential_evolution step 597: f(x)= -0.703008
# differential_evolution step 598: f(x)= -0.703008
# differential_evolution step 599: f(x)= -0.703008
# differential_evolution step 600: f(x)= -0.703008
# differential_evolution step 601: f(x)= -0.70311
# differential_evolution step 602: f(x)= -0.70311
# differential_evolution step 603: f(x)= -0.703113
# differential_evolution step 604: f(x)= -0.703113
# differential_evolution step 605: f(x)= -0.703113
# differential_evolution step 606: f(x)= -0.703284
# differential_evolution step 607: f(x)= -0.703284
# differential_evolution step 608: f(x)= -0.703885
# differential_evolution step 609: f(x)= -0.703885
# differential_evolution step 610: f(x)= -0.703885
# differential_evolution step 611: f(x)= -0.703885
# differential_evolution step 612: f(x)= -0.703885
# differential_evolution step 613: f(x)= -0.703885
# differential_evolution step 614: f(x)= -0.703885
# differential_evolution step 615: f(x)= -0.703885
# differential_evolution step 616: f(x)= -0.703885
# differential_evolution step 617: f(x)= -0.703885
# differential_evolution step 618: f(x)= -0.703885
# differential_evolution step 619: f(x)= -0.703885
# differential_evolution step 620: f(x)= -0.703885
# differential_evolution step 621: f(x)= -0.703885
# differential_evolution step 622: f(x)= -0.703885
# differential_evolution step 623: f(x)= -0.703885
# differential_evolution step 624: f(x)= -0.703885
# differential_evolution step 625: f(x)= -0.703885
# differential_evolution step 626: f(x)= -0.70395
# differential_evolution step 627: f(x)= -0.70395
# differential_evolution step 628: f(x)= -0.70395
# differential_evolution step 629: f(x)= -0.70395
# differential_evolution step 630: f(x)= -0.704062
# differential_evolution step 631: f(x)= -0.704062
# differential_evolution step 632: f(x)= -0.704062
# differential_evolution step 633: f(x)= -0.704062
# differential_evolution step 634: f(x)= -0.704062
# differential_evolution step 635: f(x)= -0.704062
# differential_evolution step 636: f(x)= -0.704062
# differential_evolution step 637: f(x)= -0.704062
# differential_evolution step 638: f(x)= -0.704062
# differential_evolution step 639: f(x)= -0.704062
# differential_evolution step 640: f(x)= -0.704062
# differential_evolution step 641: f(x)= -0.704062
# differential_evolution step 642: f(x)= -0.704484
# differential_evolution step 643: f(x)= -0.704491
# differential_evolution step 644: f(x)= -0.704491
# differential_evolution step 645: f(x)= -0.704491
# differential_evolution step 646: f(x)= -0.704491
# differential_evolution step 647: f(x)= -0.704491
# differential_evolution step 648: f(x)= -0.704491
# differential_evolution step 649: f(x)= -0.704491
# differential_evolution step 650: f(x)= -0.704605
# differential_evolution step 651: f(x)= -0.705036
# differential_evolution step 652: f(x)= -0.705036
# differential_evolution step 653: f(x)= -0.705493
# differential_evolution step 654: f(x)= -0.705493
# differential_evolution step 655: f(x)= -0.705493
# differential_evolution step 656: f(x)= -0.705493
# differential_evolution step 657: f(x)= -0.705493
# differential_evolution step 658: f(x)= -0.705546
# differential_evolution step 659: f(x)= -0.705546
# differential_evolution step 660: f(x)= -0.705546
# differential_evolution step 661: f(x)= -0.705871
# differential_evolution step 662: f(x)= -0.705871
# differential_evolution step 663: f(x)= -0.705871
# differential_evolution step 664: f(x)= -0.705871
# differential_evolution step 665: f(x)= -0.705871
# differential_evolution step 666: f(x)= -0.705871
# differential_evolution step 667: f(x)= -0.706169
# differential_evolution step 668: f(x)= -0.706169
# differential_evolution step 669: f(x)= -0.706236
# differential_evolution step 670: f(x)= -0.706499
# differential_evolution step 671: f(x)= -0.706817
# differential_evolution step 672: f(x)= -0.706817
# differential_evolution step 673: f(x)= -0.707008
# differential_evolution step 674: f(x)= -0.707008
# differential_evolution step 675: f(x)= -0.707008
# differential_evolution step 676: f(x)= -0.707008
# differential_evolution step 677: f(x)= -0.707008
# differential_evolution step 678: f(x)= -0.707008
# differential_evolution step 679: f(x)= -0.707008
# differential_evolution step 680: f(x)= -0.707008
# differential_evolution step 681: f(x)= -0.707008
# differential_evolution step 682: f(x)= -0.707008
# differential_evolution step 683: f(x)= -0.707008
# differential_evolution step 684: f(x)= -0.707445
# differential_evolution step 685: f(x)= -0.707445
# differential_evolution step 686: f(x)= -0.707445
# differential_evolution step 687: f(x)= -0.707445
# differential_evolution step 688: f(x)= -0.707445
# differential_evolution step 689: f(x)= -0.707445
# differential_evolution step 690: f(x)= -0.707445
# differential_evolution step 691: f(x)= -0.707445
# differential_evolution step 692: f(x)= -0.707445
# differential_evolution step 693: f(x)= -0.707445
# differential_evolution step 694: f(x)= -0.707445
# differential_evolution step 695: f(x)= -0.707445
# differential_evolution step 696: f(x)= -0.707445
# differential_evolution step 697: f(x)= -0.707445
# differential_evolution step 698: f(x)= -0.707445
# differential_evolution step 699: f(x)= -0.707445
# differential_evolution step 700: f(x)= -0.707451
# differential_evolution step 701: f(x)= -0.707586
# differential_evolution step 702: f(x)= -0.707586
# differential_evolution step 703: f(x)= -0.707586
# differential_evolution step 704: f(x)= -0.707586
# differential_evolution step 705: f(x)= -0.707586
# differential_evolution step 706: f(x)= -0.707586
# differential_evolution step 707: f(x)= -0.707586
# differential_evolution step 708: f(x)= -0.707607
# differential_evolution step 709: f(x)= -0.707607
# differential_evolution step 710: f(x)= -0.707607
# differential_evolution step 711: f(x)= -0.707607
# differential_evolution step 712: f(x)= -0.707607
# differential_evolution step 713: f(x)= -0.707607
# differential_evolution step 714: f(x)= -0.707749
# differential_evolution step 715: f(x)= -0.707749
# differential_evolution step 716: f(x)= -0.707749
# differential_evolution step 717: f(x)= -0.707749
# differential_evolution step 718: f(x)= -0.707749
# differential_evolution step 719: f(x)= -0.707749
# differential_evolution step 720: f(x)= -0.707749
# differential_evolution step 721: f(x)= -0.707749
# differential_evolution step 722: f(x)= -0.707749
# differential_evolution step 723: f(x)= -0.707749
# differential_evolution step 724: f(x)= -0.707749
# differential_evolution step 725: f(x)= -0.707749
# differential_evolution step 726: f(x)= -0.707749
# differential_evolution step 727: f(x)= -0.707749
# differential_evolution step 728: f(x)= -0.707749
# differential_evolution step 729: f(x)= -0.707749
# differential_evolution step 730: f(x)= -0.707749
# differential_evolution step 731: f(x)= -0.707749
# differential_evolution step 732: f(x)= -0.707749
# differential_evolution step 733: f(x)= -0.707749
# differential_evolution step 734: f(x)= -0.708007
# differential_evolution step 735: f(x)= -0.708007
# differential_evolution step 736: f(x)= -0.708007
# differential_evolution step 737: f(x)= -0.708007
# differential_evolution step 738: f(x)= -0.708007
# differential_evolution step 739: f(x)= -0.708007
# differential_evolution step 740: f(x)= -0.708007
# differential_evolution step 741: f(x)= -0.708007
# differential_evolution step 742: f(x)= -0.708007
# differential_evolution step 743: f(x)= -0.708007
# differential_evolution step 744: f(x)= -0.708007
# differential_evolution step 745: f(x)= -0.708007
# differential_evolution step 746: f(x)= -0.708007
# differential_evolution step 747: f(x)= -0.708007
# differential_evolution step 748: f(x)= -0.708007
# differential_evolution step 749: f(x)= -0.708007
# differential_evolution step 750: f(x)= -0.708007
# -0.7080069762170104 [0.88756124 0.66427986 0.28006642 0.1048181  0.16786359 0.0303035
#  0.02384908 0.02526855 0.02055275 0.05701365 0.02318119 0.05734636
#  0.02104774 0.07086416 0.02748465 0.04722257 0.11703702 0.03058798
#  0.02763835 0.02481254 0.14016581 0.08320468 0.00568323 0.50396454
#  0.25030157 0.79230033 0.89320125 0.63721199 0.83812322 0.87284134
#  0.4876458  0.37065798 0.58889242 0.19883676 0.35289821 0.48021625
#  0.59814983 0.66891055 0.64646783 0.51422341 0.48643733 0.39536628
#  0.49031814 0.35580415 0.60811162 0.94688437 0.30230954 0.91617839
#  0.26400301 0.4276667  0.68807908 0.35347087 0.83642679 0.64577894
#  0.44757439 0.98001893 0.79040028 0.3558072  0.75518376 0.64996508
#  0.65464293 0.2415582  0.17223112 0.17156366 0.10444871 0.06967729
#  0.0242854  0.04708957 0.11243624 0.08625362 0.46289941 0.05680473
#  0.10370158 0.38500663 0.08026163 0.00555586 0.01305444 0.00829163
#  0.19153103 0.02686776 0.07862656 0.47272903 0.25615924 0.22885516
#  0.75338165 0.6032544  0.8574523  0.90518308 0.83656836 0.68283296
#  0.59876236 0.94203518 0.81912452 0.32762411 0.7208054  0.43550078
#  0.49645848 0.5132264  0.51400333 0.78709923 0.15343867 0.67160468
#  0.26778491 0.34767241 0.62343879 0.81260409 0.56531512 0.1900066
#  0.69012499 0.7821652  0.84709428 0.39077589 0.68610033 0.49224378
#  0.924922   0.51108506 0.35368508 0.60689597 0.35485603 0.78066742
#  0.33921334 0.49632153 0.50127412 0.48097319 0.09654811 0.01124116
#  0.11771535 0.13353635 0.1692256  0.11800694 0.58245383 0.08505486
#  0.03300053 0.06293597 0.12180209 0.51953303 0.03242354 0.28473767
#  0.11633667 0.0743099  0.26254828 0.50384016 0.17024251 0.26721214
#  0.56642287 0.53794236 0.60875271 0.33928315 0.3578028  0.83135852
#  0.75035946 0.92158398 0.89924496 0.79651187 0.9640218  0.6823684
#  0.56015598 0.64762379 0.793279   0.62436527 0.53014731 0.71180475
#  0.34193605 0.22588188 0.26824862 0.41113416 0.38383129 0.37174168
#  0.62207676 0.30151711 0.6275085  0.61669386 0.57706711 0.57381362
#  0.44357796 0.18465753 0.45457043 0.44727373 0.06854887 0.76124114
#  0.55746001 0.51480468 0.62012758 0.24397056 0.6211016  0.57344809
#  0.59215944 0.45253313 0.74521968 0.71877277 0.46346908 0.3799324
#  0.3239327  0.52992981 0.25832707 0.4532947  0.29390848 0.42946801
#  0.38318983 0.02658232 0.32841583 0.62787333 0.2428002  0.69315586
#  0.8579999  0.32389243 0.27776322 0.61120926 0.49321067 0.49316319
#  0.27226921 0.40580232 0.76211416 0.50823911 0.32815817 0.63051923
#  0.95287568 0.58953827 0.38097741 0.71895764 0.61938309 0.30688117
#  0.55527553 0.24971095 0.10723797 0.22424269 0.13392874 0.15781092
#  0.05858387 0.11892723 0.11198002 0.10277005 0.28514028 0.35452879
#  0.10338021 0.1645999  0.35652663 0.65806531 0.82833214 0.51449014
#  0.18169795 0.53058249 0.82958159 0.64376022 0.79040821 0.6222799
#  0.62255104 0.677864   0.73347206 0.41632998 0.83781938 0.6216323
#  0.80170661 0.41375137 0.39533937 0.72591175 0.45405413 0.10180796
#  0.47710147 0.42463516 0.72006378 0.64651101 0.60914066 0.33481576
#  0.46556887 0.12280891 0.38702315 0.22720418 0.76437587 0.56537391
#  0.74861425 0.4084967  0.79968478 0.44680325 0.65886874 0.76289639
#  0.61640138 0.26816959 0.62039605 0.88731447 0.77241216 0.22412861
#  0.04072191 0.55447832 0.02085638 0.38282502 0.09672917 0.01034235
#  0.08834343 0.06497112 0.01719701 0.1961018  0.0032528  0.0117603
#  0.01334234 0.00895312 0.06098016 0.04132245 0.09531467 0.02576219
#  0.23299206 0.14788816 0.26706596 0.64943597 0.77832825 0.78140326
#  0.83633992 0.96756139 0.91583467 0.8991518 ]
# case: 1 (base reward: -0.63)
# differential_evolution step 1: f(x)= -0.662209
# differential_evolution step 2: f(x)= -0.662209
# differential_evolution step 3: f(x)= -0.662209
# differential_evolution step 4: f(x)= -0.662233
# differential_evolution step 5: f(x)= -0.665427
# differential_evolution step 6: f(x)= -0.666094
# differential_evolution step 7: f(x)= -0.666094
# differential_evolution step 8: f(x)= -0.666094
# differential_evolution step 9: f(x)= -0.666541
# differential_evolution step 10: f(x)= -0.666541
# differential_evolution step 11: f(x)= -0.666541
# differential_evolution step 12: f(x)= -0.666541
# differential_evolution step 13: f(x)= -0.666541
# differential_evolution step 14: f(x)= -0.669048
# differential_evolution step 15: f(x)= -0.669048
# differential_evolution step 16: f(x)= -0.669087
# differential_evolution step 17: f(x)= -0.669087
# differential_evolution step 18: f(x)= -0.669087
# differential_evolution step 19: f(x)= -0.669087
# differential_evolution step 20: f(x)= -0.669087
# differential_evolution step 21: f(x)= -0.669087
# differential_evolution step 22: f(x)= -0.669383
# differential_evolution step 23: f(x)= -0.672259
# differential_evolution step 24: f(x)= -0.673363
# differential_evolution step 25: f(x)= -0.674359
# differential_evolution step 26: f(x)= -0.674359
# differential_evolution step 27: f(x)= -0.674359
# differential_evolution step 28: f(x)= -0.674359
# differential_evolution step 29: f(x)= -0.675239
# differential_evolution step 30: f(x)= -0.675239
# differential_evolution step 31: f(x)= -0.675239
# differential_evolution step 32: f(x)= -0.675317
# differential_evolution step 33: f(x)= -0.675317
# differential_evolution step 34: f(x)= -0.675317
# differential_evolution step 35: f(x)= -0.675317
# differential_evolution step 36: f(x)= -0.675317
# differential_evolution step 37: f(x)= -0.675546
# differential_evolution step 38: f(x)= -0.676348
# differential_evolution step 39: f(x)= -0.676348
# differential_evolution step 40: f(x)= -0.676348
# differential_evolution step 41: f(x)= -0.677302
# differential_evolution step 42: f(x)= -0.677302
# differential_evolution step 43: f(x)= -0.677302
# differential_evolution step 44: f(x)= -0.677302
# differential_evolution step 45: f(x)= -0.678122
# differential_evolution step 46: f(x)= -0.678122
# differential_evolution step 47: f(x)= -0.678122
# differential_evolution step 48: f(x)= -0.678122
# differential_evolution step 49: f(x)= -0.678122
# differential_evolution step 50: f(x)= -0.678122
# differential_evolution step 51: f(x)= -0.678122
# differential_evolution step 52: f(x)= -0.678122
# differential_evolution step 53: f(x)= -0.678122
# differential_evolution step 54: f(x)= -0.678946
# differential_evolution step 55: f(x)= -0.678946
# differential_evolution step 56: f(x)= -0.67944
# differential_evolution step 57: f(x)= -0.67944
# differential_evolution step 58: f(x)= -0.67944
# differential_evolution step 59: f(x)= -0.67944
# differential_evolution step 60: f(x)= -0.67944
# differential_evolution step 61: f(x)= -0.67944
# differential_evolution step 62: f(x)= -0.67944
# differential_evolution step 63: f(x)= -0.67944
# differential_evolution step 64: f(x)= -0.67944
# differential_evolution step 65: f(x)= -0.67944
# differential_evolution step 66: f(x)= -0.67944
# differential_evolution step 67: f(x)= -0.679703
# differential_evolution step 68: f(x)= -0.679703
# differential_evolution step 69: f(x)= -0.680642
# differential_evolution step 70: f(x)= -0.680642
# differential_evolution step 71: f(x)= -0.681114
# differential_evolution step 72: f(x)= -0.682582
# differential_evolution step 73: f(x)= -0.683204
# differential_evolution step 74: f(x)= -0.683204
# differential_evolution step 75: f(x)= -0.683204
# differential_evolution step 76: f(x)= -0.683204
# differential_evolution step 77: f(x)= -0.683204
# differential_evolution step 78: f(x)= -0.683204
# differential_evolution step 79: f(x)= -0.683204
# differential_evolution step 80: f(x)= -0.683204
# differential_evolution step 81: f(x)= -0.683204
# differential_evolution step 82: f(x)= -0.683204
# differential_evolution step 83: f(x)= -0.683204
# differential_evolution step 84: f(x)= -0.683204
# differential_evolution step 85: f(x)= -0.683204
# differential_evolution step 86: f(x)= -0.683204
# differential_evolution step 87: f(x)= -0.684063
# differential_evolution step 88: f(x)= -0.685581
# differential_evolution step 89: f(x)= -0.686374
# differential_evolution step 90: f(x)= -0.686374
# differential_evolution step 91: f(x)= -0.686374
# differential_evolution step 92: f(x)= -0.686374
# differential_evolution step 93: f(x)= -0.686374
# differential_evolution step 94: f(x)= -0.68687
# differential_evolution step 95: f(x)= -0.68687
# differential_evolution step 96: f(x)= -0.68687
# differential_evolution step 97: f(x)= -0.68687
# differential_evolution step 98: f(x)= -0.68687
# differential_evolution step 99: f(x)= -0.68687
# differential_evolution step 100: f(x)= -0.68687
# differential_evolution step 101: f(x)= -0.68687
# differential_evolution step 102: f(x)= -0.68687
# differential_evolution step 103: f(x)= -0.68687
# differential_evolution step 104: f(x)= -0.68687
# differential_evolution step 105: f(x)= -0.68687
# differential_evolution step 106: f(x)= -0.688071
# differential_evolution step 107: f(x)= -0.688071
# differential_evolution step 108: f(x)= -0.688071
# differential_evolution step 109: f(x)= -0.688071
# differential_evolution step 110: f(x)= -0.688071
# differential_evolution step 111: f(x)= -0.688071
# differential_evolution step 112: f(x)= -0.688071
# differential_evolution step 113: f(x)= -0.688071
# differential_evolution step 114: f(x)= -0.688071
# differential_evolution step 115: f(x)= -0.688071
# differential_evolution step 116: f(x)= -0.688071
# differential_evolution step 117: f(x)= -0.688071
# differential_evolution step 118: f(x)= -0.688071
# differential_evolution step 119: f(x)= -0.688071
# differential_evolution step 120: f(x)= -0.688071
# differential_evolution step 121: f(x)= -0.688071
# differential_evolution step 122: f(x)= -0.688071
# differential_evolution step 123: f(x)= -0.688071
# differential_evolution step 124: f(x)= -0.688247
# differential_evolution step 125: f(x)= -0.688247
# differential_evolution step 126: f(x)= -0.688247
# differential_evolution step 127: f(x)= -0.688247
# differential_evolution step 128: f(x)= -0.688247
# differential_evolution step 129: f(x)= -0.688247
# differential_evolution step 130: f(x)= -0.688247
# differential_evolution step 131: f(x)= -0.688247
# differential_evolution step 132: f(x)= -0.688247
# differential_evolution step 133: f(x)= -0.688247
# differential_evolution step 134: f(x)= -0.688247
# differential_evolution step 135: f(x)= -0.688247
# differential_evolution step 136: f(x)= -0.689299
# differential_evolution step 137: f(x)= -0.689873
# differential_evolution step 138: f(x)= -0.689873
# differential_evolution step 139: f(x)= -0.689873
# differential_evolution step 140: f(x)= -0.689873
# differential_evolution step 141: f(x)= -0.689873
# differential_evolution step 142: f(x)= -0.689873
# differential_evolution step 143: f(x)= -0.689873
# differential_evolution step 144: f(x)= -0.689873
# differential_evolution step 145: f(x)= -0.689873
# differential_evolution step 146: f(x)= -0.689873
# differential_evolution step 147: f(x)= -0.689873
# differential_evolution step 148: f(x)= -0.689873
# differential_evolution step 149: f(x)= -0.689873
# differential_evolution step 150: f(x)= -0.689873
# differential_evolution step 151: f(x)= -0.689873
# differential_evolution step 152: f(x)= -0.689873
# differential_evolution step 153: f(x)= -0.689873
# differential_evolution step 154: f(x)= -0.689873
# differential_evolution step 155: f(x)= -0.689873
# differential_evolution step 156: f(x)= -0.689873
# differential_evolution step 157: f(x)= -0.689873
# differential_evolution step 158: f(x)= -0.690161
# differential_evolution step 159: f(x)= -0.690161
# differential_evolution step 160: f(x)= -0.690161
# differential_evolution step 161: f(x)= -0.690161
# differential_evolution step 162: f(x)= -0.690161
# differential_evolution step 163: f(x)= -0.690161
# differential_evolution step 164: f(x)= -0.690161
# differential_evolution step 165: f(x)= -0.690161
# differential_evolution step 166: f(x)= -0.690161
# differential_evolution step 167: f(x)= -0.690161
# ...
# differential_evolution step 262: f(x)= -0.672106
# differential_evolution step 263: f(x)= -0.672106
# differential_evolution step 264: f(x)= -0.672106
# differential_evolution step 265: f(x)= -0.672106
# differential_evolution step 266: f(x)= -0.672106
# differential_evolution step 267: f(x)= -0.672106
# differential_evolution step 268: f(x)= -0.672106
# differential_evolution step 269: f(x)= -0.672106
# differential_evolution step 270: f(x)= -0.672218
# differential_evolution step 271: f(x)= -0.672218
# differential_evolution step 272: f(x)= -0.672218
# differential_evolution step 273: f(x)= -0.672218
# differential_evolution step 274: f(x)= -0.67271
# differential_evolution step 275: f(x)= -0.67271
# differential_evolution step 276: f(x)= -0.674175
# differential_evolution step 277: f(x)= -0.674175
# differential_evolution step 278: f(x)= -0.674175
# differential_evolution step 279: f(x)= -0.674175
# differential_evolution step 280: f(x)= -0.674175
# differential_evolution step 281: f(x)= -0.674175
# differential_evolution step 282: f(x)= -0.674175
# differential_evolution step 283: f(x)= -0.674175
# differential_evolution step 284: f(x)= -0.67467
# differential_evolution step 285: f(x)= -0.67467
# differential_evolution step 286: f(x)= -0.67467
# differential_evolution step 287: f(x)= -0.67467
# differential_evolution step 288: f(x)= -0.67467
# differential_evolution step 289: f(x)= -0.675118
# differential_evolution step 290: f(x)= -0.675842
# differential_evolution step 291: f(x)= -0.675842
# differential_evolution step 292: f(x)= -0.675842
# differential_evolution step 293: f(x)= -0.675842
# differential_evolution step 294: f(x)= -0.675842
# differential_evolution step 295: f(x)= -0.675842
# differential_evolution step 296: f(x)= -0.675842
# differential_evolution step 297: f(x)= -0.675842
# differential_evolution step 298: f(x)= -0.676199
# differential_evolution step 299: f(x)= -0.676212
# differential_evolution step 300: f(x)= -0.676212
# differential_evolution step 301: f(x)= -0.676212
# differential_evolution step 302: f(x)= -0.676212
# differential_evolution step 303: f(x)= -0.676212
# differential_evolution step 304: f(x)= -0.676212
# differential_evolution step 305: f(x)= -0.676212
# differential_evolution step 306: f(x)= -0.676212
# differential_evolution step 307: f(x)= -0.676212
# differential_evolution step 308: f(x)= -0.676212
# differential_evolution step 309: f(x)= -0.676505
# differential_evolution step 310: f(x)= -0.67769
# differential_evolution step 311: f(x)= -0.67769
# differential_evolution step 312: f(x)= -0.67769
# differential_evolution step 313: f(x)= -0.67769
# differential_evolution step 314: f(x)= -0.67769
# differential_evolution step 315: f(x)= -0.67769
# differential_evolution step 316: f(x)= -0.67769
# differential_evolution step 317: f(x)= -0.67769
# differential_evolution step 318: f(x)= -0.67769
# differential_evolution step 319: f(x)= -0.67769
# differential_evolution step 320: f(x)= -0.678453
# differential_evolution step 321: f(x)= -0.678453
# differential_evolution step 322: f(x)= -0.678453
# differential_evolution step 323: f(x)= -0.678453
# differential_evolution step 324: f(x)= -0.678453
# differential_evolution step 325: f(x)= -0.678453
# differential_evolution step 326: f(x)= -0.678453
# differential_evolution step 327: f(x)= -0.678453
# differential_evolution step 328: f(x)= -0.678453
# differential_evolution step 329: f(x)= -0.678453
# differential_evolution step 330: f(x)= -0.678453
# differential_evolution step 331: f(x)= -0.678453
# differential_evolution step 332: f(x)= -0.678453
# differential_evolution step 333: f(x)= -0.678453
# differential_evolution step 334: f(x)= -0.678453
# differential_evolution step 335: f(x)= -0.678453
# differential_evolution step 336: f(x)= -0.678453
# differential_evolution step 337: f(x)= -0.678453
# differential_evolution step 338: f(x)= -0.678453
# differential_evolution step 339: f(x)= -0.678453
# differential_evolution step 340: f(x)= -0.678453
# differential_evolution step 341: f(x)= -0.678453
# differential_evolution step 342: f(x)= -0.678453
# differential_evolution step 343: f(x)= -0.678453
# differential_evolution step 344: f(x)= -0.678453
# differential_evolution step 345: f(x)= -0.678453
# differential_evolution step 346: f(x)= -0.678745
# differential_evolution step 347: f(x)= -0.678745
# differential_evolution step 348: f(x)= -0.678745
# differential_evolution step 349: f(x)= -0.678745
# differential_evolution step 350: f(x)= -0.678745
# differential_evolution step 351: f(x)= -0.678745
# differential_evolution step 352: f(x)= -0.678745
# differential_evolution step 353: f(x)= -0.678745
# differential_evolution step 354: f(x)= -0.678745
# differential_evolution step 355: f(x)= -0.678745
# differential_evolution step 356: f(x)= -0.679459
# differential_evolution step 357: f(x)= -0.679459
# differential_evolution step 358: f(x)= -0.679459
# differential_evolution step 359: f(x)= -0.679459
# differential_evolution step 360: f(x)= -0.679459
# differential_evolution step 361: f(x)= -0.679459
# differential_evolution step 362: f(x)= -0.679714
# differential_evolution step 363: f(x)= -0.679714
# differential_evolution step 364: f(x)= -0.679714
# differential_evolution step 365: f(x)= -0.679714
# differential_evolution step 366: f(x)= -0.679714
# differential_evolution step 367: f(x)= -0.679714
# differential_evolution step 368: f(x)= -0.679714
# differential_evolution step 369: f(x)= -0.679714
# differential_evolution step 370: f(x)= -0.680271
# differential_evolution step 371: f(x)= -0.680271
# differential_evolution step 372: f(x)= -0.680271
# differential_evolution step 373: f(x)= -0.680271
# differential_evolution step 374: f(x)= -0.681648
# differential_evolution step 375: f(x)= -0.681648
# differential_evolution step 376: f(x)= -0.681648
# differential_evolution step 377: f(x)= -0.681648
# differential_evolution step 378: f(x)= -0.681648
# differential_evolution step 379: f(x)= -0.681648
# differential_evolution step 380: f(x)= -0.681648
# differential_evolution step 381: f(x)= -0.681648
# differential_evolution step 382: f(x)= -0.681965
# differential_evolution step 383: f(x)= -0.681965
# differential_evolution step 384: f(x)= -0.681965
# differential_evolution step 385: f(x)= -0.681965
# differential_evolution step 386: f(x)= -0.681965
# differential_evolution step 387: f(x)= -0.681965
# differential_evolution step 388: f(x)= -0.681965
# differential_evolution step 389: f(x)= -0.681965
# differential_evolution step 390: f(x)= -0.681965
# differential_evolution step 391: f(x)= -0.681965
# differential_evolution step 392: f(x)= -0.681965
# differential_evolution step 393: f(x)= -0.681965
# differential_evolution step 394: f(x)= -0.681965
# differential_evolution step 395: f(x)= -0.682893
# differential_evolution step 396: f(x)= -0.682893
# differential_evolution step 397: f(x)= -0.682893
# differential_evolution step 398: f(x)= -0.682893
# differential_evolution step 399: f(x)= -0.682893
# differential_evolution step 400: f(x)= -0.682893
# differential_evolution step 401: f(x)= -0.682893
# differential_evolution step 402: f(x)= -0.682893
# differential_evolution step 403: f(x)= -0.682893
# differential_evolution step 404: f(x)= -0.682893
# differential_evolution step 405: f(x)= -0.682893
# differential_evolution step 406: f(x)= -0.682893
# differential_evolution step 407: f(x)= -0.682893
# differential_evolution step 408: f(x)= -0.682893
# differential_evolution step 409: f(x)= -0.682893
# differential_evolution step 410: f(x)= -0.682893
# differential_evolution step 411: f(x)= -0.682893
# differential_evolution step 412: f(x)= -0.682893
# differential_evolution step 413: f(x)= -0.682893
# differential_evolution step 414: f(x)= -0.682893
# differential_evolution step 415: f(x)= -0.682893
# differential_evolution step 416: f(x)= -0.682893
# differential_evolution step 417: f(x)= -0.682893
# differential_evolution step 418: f(x)= -0.682893
# differential_evolution step 419: f(x)= -0.682893
# differential_evolution step 420: f(x)= -0.682893
# differential_evolution step 421: f(x)= -0.682893
# differential_evolution step 422: f(x)= -0.682893
# differential_evolution step 423: f(x)= -0.682893
# differential_evolution step 424: f(x)= -0.682893
# differential_evolution step 425: f(x)= -0.682893
# differential_evolution step 426: f(x)= -0.682893
# differential_evolution step 427: f(x)= -0.682893
# differential_evolution step 428: f(x)= -0.682893
# differential_evolution step 429: f(x)= -0.682893
# differential_evolution step 430: f(x)= -0.682893
# differential_evolution step 431: f(x)= -0.682893
# differential_evolution step 432: f(x)= -0.682893
# differential_evolution step 433: f(x)= -0.682893
# differential_evolution step 434: f(x)= -0.682893
# differential_evolution step 435: f(x)= -0.682893
# differential_evolution step 436: f(x)= -0.682893
# differential_evolution step 437: f(x)= -0.682893
# differential_evolution step 438: f(x)= -0.682893
# differential_evolution step 439: f(x)= -0.682893
# differential_evolution step 440: f(x)= -0.682893
# differential_evolution step 441: f(x)= -0.683097
# differential_evolution step 442: f(x)= -0.683097
# differential_evolution step 443: f(x)= -0.683097
# differential_evolution step 444: f(x)= -0.683097
# differential_evolution step 445: f(x)= -0.683097
# differential_evolution step 446: f(x)= -0.683097
# differential_evolution step 447: f(x)= -0.683097
# differential_evolution step 448: f(x)= -0.683097
# differential_evolution step 449: f(x)= -0.683097
# differential_evolution step 450: f(x)= -0.683097
# differential_evolution step 451: f(x)= -0.683284
# differential_evolution step 452: f(x)= -0.683284
# differential_evolution step 453: f(x)= -0.683284
# differential_evolution step 454: f(x)= -0.683284
# differential_evolution step 455: f(x)= -0.6833
# differential_evolution step 456: f(x)= -0.6833
# differential_evolution step 457: f(x)= -0.6833
# differential_evolution step 458: f(x)= -0.684332
# differential_evolution step 459: f(x)= -0.684458
# differential_evolution step 460: f(x)= -0.684515
# differential_evolution step 461: f(x)= -0.684515
# differential_evolution step 462: f(x)= -0.684515
# differential_evolution step 463: f(x)= -0.684515
# differential_evolution step 464: f(x)= -0.684545
# differential_evolution step 465: f(x)= -0.684545
# differential_evolution step 466: f(x)= -0.684545
# differential_evolution step 467: f(x)= -0.684545
# differential_evolution step 468: f(x)= -0.684839
# differential_evolution step 469: f(x)= -0.684839
# differential_evolution step 470: f(x)= -0.684839
# differential_evolution step 471: f(x)= -0.684839
# differential_evolution step 472: f(x)= -0.684839
# differential_evolution step 473: f(x)= -0.685704
# differential_evolution step 474: f(x)= -0.685704
# differential_evolution step 475: f(x)= -0.685704
# differential_evolution step 476: f(x)= -0.685704
# differential_evolution step 477: f(x)= -0.685704
# differential_evolution step 478: f(x)= -0.685949
# differential_evolution step 479: f(x)= -0.685949
# differential_evolution step 480: f(x)= -0.685949
# differential_evolution step 481: f(x)= -0.685949
# differential_evolution step 482: f(x)= -0.685949
# differential_evolution step 483: f(x)= -0.685949
# differential_evolution step 484: f(x)= -0.685949
# differential_evolution step 485: f(x)= -0.685949
# differential_evolution step 486: f(x)= -0.685949
# differential_evolution step 487: f(x)= -0.685949
# differential_evolution step 488: f(x)= -0.685949
# differential_evolution step 489: f(x)= -0.685949
# differential_evolution step 490: f(x)= -0.685949
# differential_evolution step 491: f(x)= -0.685949
# differential_evolution step 492: f(x)= -0.685949
# differential_evolution step 493: f(x)= -0.685949
# differential_evolution step 494: f(x)= -0.685949
# differential_evolution step 495: f(x)= -0.685949
# differential_evolution step 496: f(x)= -0.685949
# differential_evolution step 497: f(x)= -0.685949
# differential_evolution step 498: f(x)= -0.685949
# differential_evolution step 499: f(x)= -0.685949
# differential_evolution step 500: f(x)= -0.685949
# differential_evolution step 501: f(x)= -0.685949
# differential_evolution step 502: f(x)= -0.685949
# differential_evolution step 503: f(x)= -0.685949
# differential_evolution step 504: f(x)= -0.685949
# differential_evolution step 505: f(x)= -0.685949
# differential_evolution step 506: f(x)= -0.685949
# differential_evolution step 507: f(x)= -0.686171
# differential_evolution step 508: f(x)= -0.686171
# differential_evolution step 509: f(x)= -0.686171
# differential_evolution step 510: f(x)= -0.686171
# differential_evolution step 511: f(x)= -0.686171
# differential_evolution step 512: f(x)= -0.686171
# differential_evolution step 513: f(x)= -0.686614
# differential_evolution step 514: f(x)= -0.686614
# differential_evolution step 515: f(x)= -0.686614
# differential_evolution step 516: f(x)= -0.686614
# differential_evolution step 517: f(x)= -0.686614
# differential_evolution step 518: f(x)= -0.686614
# differential_evolution step 519: f(x)= -0.686614
# differential_evolution step 520: f(x)= -0.686934
# differential_evolution step 521: f(x)= -0.687288
# differential_evolution step 522: f(x)= -0.687288
# differential_evolution step 523: f(x)= -0.687288
# differential_evolution step 524: f(x)= -0.687288
# differential_evolution step 525: f(x)= -0.687976
# differential_evolution step 526: f(x)= -0.687976
# differential_evolution step 527: f(x)= -0.687976
# differential_evolution step 528: f(x)= -0.687976
# differential_evolution step 529: f(x)= -0.687976
# differential_evolution step 530: f(x)= -0.687976
# differential_evolution step 531: f(x)= -0.687976
# differential_evolution step 532: f(x)= -0.687976
# differential_evolution step 533: f(x)= -0.687976
# differential_evolution step 534: f(x)= -0.687976
# differential_evolution step 535: f(x)= -0.687976
# differential_evolution step 536: f(x)= -0.687976
# differential_evolution step 537: f(x)= -0.687976
# differential_evolution step 538: f(x)= -0.687976
# differential_evolution step 539: f(x)= -0.687976
# differential_evolution step 540: f(x)= -0.687976
# differential_evolution step 541: f(x)= -0.687976
# differential_evolution step 542: f(x)= -0.687976
# differential_evolution step 543: f(x)= -0.687976
# differential_evolution step 544: f(x)= -0.687976
# differential_evolution step 545: f(x)= -0.687976
# differential_evolution step 546: f(x)= -0.687976
# differential_evolution step 547: f(x)= -0.687976
# differential_evolution step 548: f(x)= -0.687976
# differential_evolution step 549: f(x)= -0.687976
# differential_evolution step 550: f(x)= -0.687976
# differential_evolution step 551: f(x)= -0.687976
# differential_evolution step 552: f(x)= -0.687976
# differential_evolution step 553: f(x)= -0.687976
# differential_evolution step 554: f(x)= -0.687976
# differential_evolution step 555: f(x)= -0.687976
# differential_evolution step 556: f(x)= -0.687976
# differential_evolution step 557: f(x)= -0.687976
# differential_evolution step 558: f(x)= -0.687976
# differential_evolution step 559: f(x)= -0.687976
# differential_evolution step 560: f(x)= -0.687976
# differential_evolution step 561: f(x)= -0.687976
# differential_evolution step 562: f(x)= -0.687976
# differential_evolution step 563: f(x)= -0.687976
# differential_evolution step 564: f(x)= -0.688452
# differential_evolution step 565: f(x)= -0.688452
# differential_evolution step 566: f(x)= -0.688452
# differential_evolution step 567: f(x)= -0.688452
# differential_evolution step 568: f(x)= -0.688452
# differential_evolution step 569: f(x)= -0.688452
# differential_evolution step 570: f(x)= -0.688452
# differential_evolution step 571: f(x)= -0.688452
# differential_evolution step 572: f(x)= -0.688452
# differential_evolution step 573: f(x)= -0.688452
# differential_evolution step 574: f(x)= -0.688452
# differential_evolution step 575: f(x)= -0.688452
# differential_evolution step 576: f(x)= -0.688452
# differential_evolution step 577: f(x)= -0.688452
# differential_evolution step 578: f(x)= -0.688452
# differential_evolution step 579: f(x)= -0.688452
# differential_evolution step 580: f(x)= -0.688452
# differential_evolution step 581: f(x)= -0.688452
# differential_evolution step 582: f(x)= -0.688452
# differential_evolution step 583: f(x)= -0.688452
# differential_evolution step 584: f(x)= -0.688452
# differential_evolution step 585: f(x)= -0.688452
# differential_evolution step 586: f(x)= -0.688452
# differential_evolution step 587: f(x)= -0.688452
# differential_evolution step 588: f(x)= -0.688452
