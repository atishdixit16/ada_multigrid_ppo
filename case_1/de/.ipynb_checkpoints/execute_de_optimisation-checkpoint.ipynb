# %%
# to access functions from root directory 
import sys
sys.path.append('/data/ad181/RemoteDir/rl_robust_owc')

# %%
# %matplotlib notebook
from utils.plot_functions import plot_s_animation, plot_s_snapshots

import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.optimize import differential_evolution

from utils.env_evaluate_functions import eval_actions
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case = 'case_1'
opt_dir = './'+case
os.makedirs(opt_dir, exist_ok=True)

# %%
with open('../envs_params/env_data/env_list_eval.pkl', 'rb') as input:
    envs = pickle.load(input)
rl_indices = list(range(16))

# %%
def objective_function(q_arg, *args ):
    env = args[0]
    assert q_arg.size == env.terminal_step*env.action_space.shape[0], 'invalid argument size'
    q_arg = q_arg.reshape(env.terminal_step, -1)
    _,_, rewards = eval_actions(env, q_arg)
    return -sum(rewards)

# %%
for i,env in enumerate(envs):
    if i in rl_indices:
        args = (env,)
        base_action = np.ones((env.terminal_step,env.action_space.shape[0]))
        _,_, rewards = eval_actions(env, base_action)
        print(f'case: {i} (base reward: {-round(sum(rewards), 2)})')
        bounds =  [(env.action_space.low[0],env.action_space.high[0])]*(env.terminal_step*env.action_space.shape[0])
        result = differential_evolution(objective_function, bounds, args=args,
                                    maxiter=750, popsize=1, tol=1e-5,
                                    disp=True, polish=False,
                                    recombination=0.9, mutation=(0.5,1),
                                    updating='deferred', workers=64, seed=seed)
        np.save(opt_dir+'/ck_argmax_'+str(i)+'.npy', result.x)
        np.save(opt_dir+'/ck_max_'+str(i)+'.npy', result.fun)
        print(result.fun, result.x)
# Out:
# case: 0 (base reward: -0.6)
# differential_evolution step 1: f(x)= -0.628002
# differential_evolution step 2: f(x)= -0.633919
# differential_evolution step 3: f(x)= -0.636846
# differential_evolution step 4: f(x)= -0.639986
# differential_evolution step 5: f(x)= -0.640809
# differential_evolution step 6: f(x)= -0.640809
# differential_evolution step 7: f(x)= -0.640809
# differential_evolution step 8: f(x)= -0.640809
# differential_evolution step 9: f(x)= -0.640809
# differential_evolution step 10: f(x)= -0.640809
# differential_evolution step 11: f(x)= -0.643697
# differential_evolution step 12: f(x)= -0.643697
# differential_evolution step 13: f(x)= -0.643697
# differential_evolution step 14: f(x)= -0.643697
# differential_evolution step 15: f(x)= -0.644059
# differential_evolution step 16: f(x)= -0.644059
# differential_evolution step 17: f(x)= -0.644059
# differential_evolution step 18: f(x)= -0.644059
# differential_evolution step 19: f(x)= -0.644059
# differential_evolution step 20: f(x)= -0.644059
# differential_evolution step 21: f(x)= -0.644059
# differential_evolution step 22: f(x)= -0.645523
# differential_evolution step 23: f(x)= -0.645523
# differential_evolution step 24: f(x)= -0.645523
# differential_evolution step 25: f(x)= -0.649187
# differential_evolution step 26: f(x)= -0.649187
# differential_evolution step 27: f(x)= -0.649187
# differential_evolution step 28: f(x)= -0.649187
# differential_evolution step 29: f(x)= -0.649187
# differential_evolution step 30: f(x)= -0.650991
# differential_evolution step 31: f(x)= -0.650991
# differential_evolution step 32: f(x)= -0.650991
# differential_evolution step 33: f(x)= -0.650991
# differential_evolution step 34: f(x)= -0.653337
# differential_evolution step 35: f(x)= -0.653337
# differential_evolution step 36: f(x)= -0.653337
# differential_evolution step 37: f(x)= -0.653337
# differential_evolution step 38: f(x)= -0.653337
# differential_evolution step 39: f(x)= -0.653337
# differential_evolution step 40: f(x)= -0.653337
# differential_evolution step 41: f(x)= -0.653337
# differential_evolution step 42: f(x)= -0.653337
# differential_evolution step 43: f(x)= -0.653337
# differential_evolution step 44: f(x)= -0.653337
# differential_evolution step 45: f(x)= -0.653337
# differential_evolution step 46: f(x)= -0.653337
# differential_evolution step 47: f(x)= -0.653337
# differential_evolution step 48: f(x)= -0.653337
# differential_evolution step 49: f(x)= -0.654376
# differential_evolution step 50: f(x)= -0.654376
# differential_evolution step 51: f(x)= -0.654376
# differential_evolution step 52: f(x)= -0.654376
# differential_evolution step 53: f(x)= -0.657799
# differential_evolution step 54: f(x)= -0.659404
# differential_evolution step 55: f(x)= -0.661081
# differential_evolution step 56: f(x)= -0.661081
# differential_evolution step 57: f(x)= -0.661592
# differential_evolution step 58: f(x)= -0.663478
# differential_evolution step 59: f(x)= -0.663478
# differential_evolution step 60: f(x)= -0.663618
# differential_evolution step 61: f(x)= -0.663618
# differential_evolution step 62: f(x)= -0.663618
# differential_evolution step 63: f(x)= -0.663618
# differential_evolution step 64: f(x)= -0.663618
# differential_evolution step 65: f(x)= -0.663618
# differential_evolution step 66: f(x)= -0.663618
# differential_evolution step 67: f(x)= -0.663618
# differential_evolution step 68: f(x)= -0.663618
# differential_evolution step 69: f(x)= -0.663618
# differential_evolution step 70: f(x)= -0.663618
# differential_evolution step 71: f(x)= -0.663618
# differential_evolution step 72: f(x)= -0.663618
# differential_evolution step 73: f(x)= -0.663618
# differential_evolution step 74: f(x)= -0.663618
# differential_evolution step 75: f(x)= -0.663618
# differential_evolution step 76: f(x)= -0.663618
# differential_evolution step 77: f(x)= -0.663618
# differential_evolution step 78: f(x)= -0.663618
# differential_evolution step 79: f(x)= -0.667189
# differential_evolution step 80: f(x)= -0.667189
# differential_evolution step 81: f(x)= -0.667189
# differential_evolution step 82: f(x)= -0.667189
# differential_evolution step 83: f(x)= -0.667189
# differential_evolution step 84: f(x)= -0.667189
# differential_evolution step 85: f(x)= -0.667189
# differential_evolution step 86: f(x)= -0.667189
# differential_evolution step 87: f(x)= -0.667189
# differential_evolution step 88: f(x)= -0.667189
# differential_evolution step 89: f(x)= -0.667189
# differential_evolution step 90: f(x)= -0.667189
# differential_evolution step 91: f(x)= -0.667189
# differential_evolution step 92: f(x)= -0.667189
# differential_evolution step 93: f(x)= -0.667189
# differential_evolution step 94: f(x)= -0.667189
# differential_evolution step 95: f(x)= -0.667189
# differential_evolution step 96: f(x)= -0.667189
# differential_evolution step 97: f(x)= -0.667189
# differential_evolution step 98: f(x)= -0.668559
# differential_evolution step 99: f(x)= -0.668922
# differential_evolution step 100: f(x)= -0.668922
# differential_evolution step 101: f(x)= -0.668922
# differential_evolution step 102: f(x)= -0.668922
# differential_evolution step 103: f(x)= -0.669739
# differential_evolution step 104: f(x)= -0.670198
# differential_evolution step 105: f(x)= -0.670198
# differential_evolution step 106: f(x)= -0.670198
# differential_evolution step 107: f(x)= -0.670198
# differential_evolution step 108: f(x)= -0.670198
# differential_evolution step 109: f(x)= -0.670198
# differential_evolution step 110: f(x)= -0.670198
# differential_evolution step 111: f(x)= -0.671699
# differential_evolution step 112: f(x)= -0.671699
# differential_evolution step 113: f(x)= -0.671699
# differential_evolution step 114: f(x)= -0.671699
# differential_evolution step 115: f(x)= -0.671699
# differential_evolution step 116: f(x)= -0.671877
# differential_evolution step 117: f(x)= -0.671877
# differential_evolution step 118: f(x)= -0.671877
# differential_evolution step 119: f(x)= -0.671877
# differential_evolution step 120: f(x)= -0.671877
# differential_evolution step 121: f(x)= -0.671877
# differential_evolution step 122: f(x)= -0.671877
# differential_evolution step 123: f(x)= -0.671877
# differential_evolution step 124: f(x)= -0.674836
# differential_evolution step 125: f(x)= -0.674836
# differential_evolution step 126: f(x)= -0.674836
# differential_evolution step 127: f(x)= -0.674912
# differential_evolution step 128: f(x)= -0.674912
# differential_evolution step 129: f(x)= -0.674912
# differential_evolution step 130: f(x)= -0.674912
# differential_evolution step 131: f(x)= -0.674912
# differential_evolution step 132: f(x)= -0.674912
# differential_evolution step 133: f(x)= -0.674912
# differential_evolution step 134: f(x)= -0.674912
# differential_evolution step 135: f(x)= -0.674912
# differential_evolution step 136: f(x)= -0.674912
# differential_evolution step 137: f(x)= -0.674912
# differential_evolution step 138: f(x)= -0.674912
# differential_evolution step 139: f(x)= -0.674912
# differential_evolution step 140: f(x)= -0.674912
# differential_evolution step 141: f(x)= -0.674912
# differential_evolution step 142: f(x)= -0.674912
# differential_evolution step 143: f(x)= -0.674912
# differential_evolution step 144: f(x)= -0.674912
# differential_evolution step 145: f(x)= -0.674912
# differential_evolution step 146: f(x)= -0.674912
# differential_evolution step 147: f(x)= -0.674981
# differential_evolution step 148: f(x)= -0.674981
# differential_evolution step 149: f(x)= -0.674981
# differential_evolution step 150: f(x)= -0.674981
# differential_evolution step 151: f(x)= -0.676671
# differential_evolution step 152: f(x)= -0.676671
# differential_evolution step 153: f(x)= -0.676671
# differential_evolution step 154: f(x)= -0.676671
# differential_evolution step 155: f(x)= -0.676671
# differential_evolution step 156: f(x)= -0.676671
# differential_evolution step 157: f(x)= -0.677404
# differential_evolution step 158: f(x)= -0.677404
# differential_evolution step 159: f(x)= -0.677404
# differential_evolution step 160: f(x)= -0.677404
# differential_evolution step 161: f(x)= -0.677404
# differential_evolution step 162: f(x)= -0.677404
# differential_evolution step 163: f(x)= -0.677404
# differential_evolution step 164: f(x)= -0.677404
# differential_evolution step 165: f(x)= -0.677404
# differential_evolution step 166: f(x)= -0.677404
# differential_evolution step 167: f(x)= -0.677404
# differential_evolution step 168: f(x)= -0.677404
# differential_evolution step 169: f(x)= -0.677404
# differential_evolution step 170: f(x)= -0.677404
# differential_evolution step 171: f(x)= -0.677404
# differential_evolution step 172: f(x)= -0.677404
# differential_evolution step 173: f(x)= -0.677404
# differential_evolution step 174: f(x)= -0.677404
# differential_evolution step 175: f(x)= -0.677404
# differential_evolution step 176: f(x)= -0.677404
# differential_evolution step 177: f(x)= -0.677404
# differential_evolution step 178: f(x)= -0.677404
# differential_evolution step 179: f(x)= -0.677404
# differential_evolution step 180: f(x)= -0.677404
# differential_evolution step 181: f(x)= -0.677404
# differential_evolution step 182: f(x)= -0.677404
# differential_evolution step 183: f(x)= -0.677404
# differential_evolution step 184: f(x)= -0.677404
# differential_evolution step 185: f(x)= -0.677404
# differential_evolution step 186: f(x)= -0.677522
# differential_evolution step 187: f(x)= -0.677522
# differential_evolution step 188: f(x)= -0.678083
# differential_evolution step 189: f(x)= -0.678083
# differential_evolution step 190: f(x)= -0.678083
# differential_evolution step 191: f(x)= -0.678083
# differential_evolution step 192: f(x)= -0.678778
# differential_evolution step 193: f(x)= -0.678778
# differential_evolution step 194: f(x)= -0.679792
# differential_evolution step 195: f(x)= -0.679792
# differential_evolution step 196: f(x)= -0.680928
# differential_evolution step 197: f(x)= -0.680928
# differential_evolution step 198: f(x)= -0.680928
# differential_evolution step 199: f(x)= -0.681019
# differential_evolution step 200: f(x)= -0.681256
# differential_evolution step 201: f(x)= -0.681256
# differential_evolution step 202: f(x)= -0.681256
# differential_evolution step 203: f(x)= -0.681256
# differential_evolution step 204: f(x)= -0.681256
# differential_evolution step 205: f(x)= -0.682714
# differential_evolution step 206: f(x)= -0.682714
# differential_evolution step 207: f(x)= -0.682714
# differential_evolution step 208: f(x)= -0.682714
# differential_evolution step 209: f(x)= -0.682714
# differential_evolution step 210: f(x)= -0.682714
# differential_evolution step 211: f(x)= -0.682714
# differential_evolution step 212: f(x)= -0.682714
# differential_evolution step 213: f(x)= -0.682714
# differential_evolution step 214: f(x)= -0.682714
# differential_evolution step 215: f(x)= -0.682855
# differential_evolution step 216: f(x)= -0.682855
# differential_evolution step 217: f(x)= -0.682855
# differential_evolution step 218: f(x)= -0.682855
# differential_evolution step 219: f(x)= -0.682855
# differential_evolution step 220: f(x)= -0.682855
# differential_evolution step 221: f(x)= -0.682855
# differential_evolution step 222: f(x)= -0.682855
# differential_evolution step 223: f(x)= -0.682855
# differential_evolution step 224: f(x)= -0.682855
# differential_evolution step 225: f(x)= -0.682855
# differential_evolution step 226: f(x)= -0.682855
# differential_evolution step 227: f(x)= -0.683367
# differential_evolution step 228: f(x)= -0.683367
# differential_evolution step 229: f(x)= -0.683367
# differential_evolution step 230: f(x)= -0.683367
# differential_evolution step 231: f(x)= -0.683367
# differential_evolution step 232: f(x)= -0.683367
# differential_evolution step 233: f(x)= -0.683367
# differential_evolution step 234: f(x)= -0.683367
# differential_evolution step 235: f(x)= -0.683367
# differential_evolution step 236: f(x)= -0.683367
# differential_evolution step 237: f(x)= -0.683396
# differential_evolution step 238: f(x)= -0.683396
# differential_evolution step 239: f(x)= -0.683396
# differential_evolution step 240: f(x)= -0.683396
# differential_evolution step 241: f(x)= -0.683396
# differential_evolution step 242: f(x)= -0.683396
# differential_evolution step 243: f(x)= -0.683396
# differential_evolution step 244: f(x)= -0.683396
# differential_evolution step 245: f(x)= -0.683396
# differential_evolution step 246: f(x)= -0.683396
# differential_evolution step 247: f(x)= -0.683396
# differential_evolution step 248: f(x)= -0.683396
# differential_evolution step 249: f(x)= -0.683396
# differential_evolution step 250: f(x)= -0.683396
# differential_evolution step 251: f(x)= -0.683556
# differential_evolution step 252: f(x)= -0.683556
# differential_evolution step 253: f(x)= -0.683556
# differential_evolution step 254: f(x)= -0.683556
# differential_evolution step 255: f(x)= -0.683556
# differential_evolution step 256: f(x)= -0.683556
# differential_evolution step 257: f(x)= -0.684674
# differential_evolution step 258: f(x)= -0.686076
# differential_evolution step 259: f(x)= -0.686076
# differential_evolution step 260: f(x)= -0.686076
# differential_evolution step 261: f(x)= -0.686076
# differential_evolution step 262: f(x)= -0.686076
# differential_evolution step 263: f(x)= -0.686223
# differential_evolution step 264: f(x)= -0.686223
# differential_evolution step 265: f(x)= -0.686424
# differential_evolution step 266: f(x)= -0.686424
# differential_evolution step 267: f(x)= -0.686899
# differential_evolution step 268: f(x)= -0.686899
# differential_evolution step 269: f(x)= -0.686899
# differential_evolution step 270: f(x)= -0.686899
# differential_evolution step 271: f(x)= -0.686899
# differential_evolution step 272: f(x)= -0.686899
# differential_evolution step 273: f(x)= -0.686899
# differential_evolution step 274: f(x)= -0.686899
# differential_evolution step 275: f(x)= -0.686899
# differential_evolution step 276: f(x)= -0.686899
# differential_evolution step 277: f(x)= -0.686899
# differential_evolution step 278: f(x)= -0.687668
# differential_evolution step 279: f(x)= -0.687668
# differential_evolution step 280: f(x)= -0.687668
# differential_evolution step 281: f(x)= -0.687668
# differential_evolution step 282: f(x)= -0.687668
# differential_evolution step 283: f(x)= -0.687668
# differential_evolution step 284: f(x)= -0.687668
# differential_evolution step 285: f(x)= -0.687668
# differential_evolution step 286: f(x)= -0.687668
# differential_evolution step 287: f(x)= -0.687668
# differential_evolution step 288: f(x)= -0.687668
# differential_evolution step 289: f(x)= -0.687668
# differential_evolution step 290: f(x)= -0.687668
# differential_evolution step 291: f(x)= -0.68771
# differential_evolution step 292: f(x)= -0.68771
# differential_evolution step 293: f(x)= -0.68771
# differential_evolution step 294: f(x)= -0.68771
# differential_evolution step 295: f(x)= -0.68771
# differential_evolution step 296: f(x)= -0.68771
# differential_evolution step 297: f(x)= -0.68771
# differential_evolution step 298: f(x)= -0.68771
# differential_evolution step 299: f(x)= -0.68771
# differential_evolution step 300: f(x)= -0.68771
# differential_evolution step 301: f(x)= -0.68771
# differential_evolution step 302: f(x)= -0.68771
# differential_evolution step 303: f(x)= -0.68771
# differential_evolution step 304: f(x)= -0.68771
# differential_evolution step 305: f(x)= -0.68771
# differential_evolution step 306: f(x)= -0.68771
# differential_evolution step 307: f(x)= -0.68771
# differential_evolution step 308: f(x)= -0.68771
# differential_evolution step 309: f(x)= -0.68771
# differential_evolution step 310: f(x)= -0.68771
# differential_evolution step 311: f(x)= -0.688678
# differential_evolution step 312: f(x)= -0.688678
# differential_evolution step 313: f(x)= -0.688678
# differential_evolution step 314: f(x)= -0.688678
# differential_evolution step 315: f(x)= -0.688678
# differential_evolution step 316: f(x)= -0.688678
# differential_evolution step 317: f(x)= -0.688863
# differential_evolution step 318: f(x)= -0.688863
# differential_evolution step 319: f(x)= -0.688863
# differential_evolution step 320: f(x)= -0.688863
# differential_evolution step 321: f(x)= -0.689139
# differential_evolution step 322: f(x)= -0.689254
# differential_evolution step 323: f(x)= -0.689254
# differential_evolution step 324: f(x)= -0.689254
# differential_evolution step 325: f(x)= -0.689417
# differential_evolution step 326: f(x)= -0.690533
# differential_evolution step 327: f(x)= -0.690533
# differential_evolution step 328: f(x)= -0.690533
# differential_evolution step 329: f(x)= -0.690533
# differential_evolution step 330: f(x)= -0.690533
# differential_evolution step 331: f(x)= -0.690533
# differential_evolution step 332: f(x)= -0.690533
# differential_evolution step 333: f(x)= -0.690533
# differential_evolution step 334: f(x)= -0.690533
# differential_evolution step 335: f(x)= -0.690533
# differential_evolution step 336: f(x)= -0.690533
# differential_evolution step 337: f(x)= -0.690533
# differential_evolution step 338: f(x)= -0.690533
# differential_evolution step 339: f(x)= -0.690533
# differential_evolution step 340: f(x)= -0.690533
# differential_evolution step 341: f(x)= -0.690783
# differential_evolution step 342: f(x)= -0.691285
# differential_evolution step 343: f(x)= -0.691285
# differential_evolution step 344: f(x)= -0.691285
# differential_evolution step 345: f(x)= -0.691285
# differential_evolution step 346: f(x)= -0.691285
# differential_evolution step 347: f(x)= -0.691285
# differential_evolution step 348: f(x)= -0.691285
# differential_evolution step 349: f(x)= -0.691304
# differential_evolution step 350: f(x)= -0.691853
# differential_evolution step 351: f(x)= -0.692153
# differential_evolution step 352: f(x)= -0.692153
# differential_evolution step 353: f(x)= -0.692153
# differential_evolution step 354: f(x)= -0.692153
# differential_evolution step 355: f(x)= -0.692153
# differential_evolution step 356: f(x)= -0.692153
# differential_evolution step 357: f(x)= -0.692153
# differential_evolution step 358: f(x)= -0.692153
# differential_evolution step 359: f(x)= -0.692153
# differential_evolution step 360: f(x)= -0.692153
# differential_evolution step 361: f(x)= -0.692153
# differential_evolution step 362: f(x)= -0.692153
# differential_evolution step 363: f(x)= -0.692153
# differential_evolution step 364: f(x)= -0.692153
# differential_evolution step 365: f(x)= -0.692153
# differential_evolution step 366: f(x)= -0.692229
# differential_evolution step 367: f(x)= -0.692229
# differential_evolution step 368: f(x)= -0.692229
# differential_evolution step 369: f(x)= -0.692287
# differential_evolution step 370: f(x)= -0.692355
# differential_evolution step 371: f(x)= -0.692779
# differential_evolution step 372: f(x)= -0.693275
# differential_evolution step 373: f(x)= -0.693275
# differential_evolution step 374: f(x)= -0.693893
# differential_evolution step 375: f(x)= -0.69391
# differential_evolution step 376: f(x)= -0.69391
# differential_evolution step 377: f(x)= -0.69391
# differential_evolution step 378: f(x)= -0.693944
# differential_evolution step 379: f(x)= -0.693944
# differential_evolution step 380: f(x)= -0.693944
# differential_evolution step 381: f(x)= -0.693944
# differential_evolution step 382: f(x)= -0.695023
# differential_evolution step 383: f(x)= -0.695023
# differential_evolution step 384: f(x)= -0.695023
# differential_evolution step 385: f(x)= -0.69529
# differential_evolution step 386: f(x)= -0.69529
# differential_evolution step 387: f(x)= -0.69529
# differential_evolution step 388: f(x)= -0.69529
# differential_evolution step 389: f(x)= -0.69529
# differential_evolution step 390: f(x)= -0.69529
# differential_evolution step 391: f(x)= -0.69529
# differential_evolution step 392: f(x)= -0.69529
# differential_evolution step 393: f(x)= -0.69529
# differential_evolution step 394: f(x)= -0.69529
# differential_evolution step 395: f(x)= -0.69529
# differential_evolution step 396: f(x)= -0.69529
# differential_evolution step 397: f(x)= -0.69529
# differential_evolution step 398: f(x)= -0.69529
# differential_evolution step 399: f(x)= -0.69529
# differential_evolution step 400: f(x)= -0.69529
# differential_evolution step 401: f(x)= -0.69529
# differential_evolution step 402: f(x)= -0.69529
# differential_evolution step 403: f(x)= -0.69529
# differential_evolution step 404: f(x)= -0.69529
# differential_evolution step 405: f(x)= -0.69529
# differential_evolution step 406: f(x)= -0.69529
# differential_evolution step 407: f(x)= -0.69529
# differential_evolution step 408: f(x)= -0.69529
# differential_evolution step 409: f(x)= -0.69529
# differential_evolution step 410: f(x)= -0.69529
# differential_evolution step 411: f(x)= -0.69529
# differential_evolution step 412: f(x)= -0.69529
# differential_evolution step 413: f(x)= -0.69529
# differential_evolution step 414: f(x)= -0.69529
# differential_evolution step 415: f(x)= -0.69529
# differential_evolution step 416: f(x)= -0.69529
# differential_evolution step 417: f(x)= -0.69529
# differential_evolution step 418: f(x)= -0.69529
# differential_evolution step 419: f(x)= -0.69529
# differential_evolution step 420: f(x)= -0.69529
# differential_evolution step 421: f(x)= -0.69529
# differential_evolution step 422: f(x)= -0.69529
# differential_evolution step 423: f(x)= -0.69529
# differential_evolution step 424: f(x)= -0.69529
# differential_evolution step 425: f(x)= -0.69529
# differential_evolution step 426: f(x)= -0.69529
# differential_evolution step 427: f(x)= -0.69529
# differential_evolution step 428: f(x)= -0.69529
# differential_evolution step 429: f(x)= -0.69529
# differential_evolution step 430: f(x)= -0.69529
# differential_evolution step 431: f(x)= -0.69529
# differential_evolution step 432: f(x)= -0.69529
# differential_evolution step 433: f(x)= -0.69529
# differential_evolution step 434: f(x)= -0.695761
# differential_evolution step 435: f(x)= -0.696161
# differential_evolution step 436: f(x)= -0.696161
# differential_evolution step 437: f(x)= -0.696502
# differential_evolution step 438: f(x)= -0.696502
# differential_evolution step 439: f(x)= -0.696502
# differential_evolution step 440: f(x)= -0.696502
# differential_evolution step 441: f(x)= -0.696502
# differential_evolution step 442: f(x)= -0.696502
# differential_evolution step 443: f(x)= -0.696502
# differential_evolution step 444: f(x)= -0.696674
# differential_evolution step 445: f(x)= -0.696867
# differential_evolution step 446: f(x)= -0.696867
# differential_evolution step 447: f(x)= -0.697013
# differential_evolution step 448: f(x)= -0.697666
# differential_evolution step 449: f(x)= -0.697666
# differential_evolution step 450: f(x)= -0.697666
# differential_evolution step 451: f(x)= -0.697666
# differential_evolution step 452: f(x)= -0.697666
# differential_evolution step 453: f(x)= -0.697666
# differential_evolution step 454: f(x)= -0.697984
# differential_evolution step 455: f(x)= -0.697984
# differential_evolution step 456: f(x)= -0.697984
# differential_evolution step 457: f(x)= -0.698452
# differential_evolution step 458: f(x)= -0.698452
# differential_evolution step 459: f(x)= -0.698452
# differential_evolution step 460: f(x)= -0.698452
# differential_evolution step 461: f(x)= -0.698452
# differential_evolution step 462: f(x)= -0.698452
# differential_evolution step 463: f(x)= -0.698452
# differential_evolution step 464: f(x)= -0.698452
# differential_evolution step 465: f(x)= -0.698452
# differential_evolution step 466: f(x)= -0.698452
# differential_evolution step 467: f(x)= -0.698452
# differential_evolution step 468: f(x)= -0.698452
# differential_evolution step 469: f(x)= -0.698452
# differential_evolution step 470: f(x)= -0.698452
# differential_evolution step 471: f(x)= -0.698452
# differential_evolution step 472: f(x)= -0.698452
# differential_evolution step 473: f(x)= -0.698452
# differential_evolution step 474: f(x)= -0.698452
# differential_evolution step 475: f(x)= -0.698452
# differential_evolution step 476: f(x)= -0.698452
# differential_evolution step 477: f(x)= -0.698452
# differential_evolution step 478: f(x)= -0.698452
# differential_evolution step 479: f(x)= -0.698452
# differential_evolution step 480: f(x)= -0.698452
# differential_evolution step 481: f(x)= -0.698648
# differential_evolution step 482: f(x)= -0.698997
# differential_evolution step 483: f(x)= -0.699641
# differential_evolution step 484: f(x)= -0.699641
# differential_evolution step 485: f(x)= -0.699641
# differential_evolution step 486: f(x)= -0.699641
# differential_evolution step 487: f(x)= -0.699641
# differential_evolution step 488: f(x)= -0.699641
# differential_evolution step 489: f(x)= -0.699841
# differential_evolution step 490: f(x)= -0.699841
# differential_evolution step 491: f(x)= -0.699841
# differential_evolution step 492: f(x)= -0.699841
# differential_evolution step 493: f(x)= -0.699841
# differential_evolution step 494: f(x)= -0.699841
# differential_evolution step 495: f(x)= -0.699841
# differential_evolution step 496: f(x)= -0.699841
# differential_evolution step 497: f(x)= -0.699841
# differential_evolution step 498: f(x)= -0.700192
# differential_evolution step 499: f(x)= -0.700192
# differential_evolution step 500: f(x)= -0.700192
# differential_evolution step 501: f(x)= -0.700192
# differential_evolution step 502: f(x)= -0.700231
# differential_evolution step 503: f(x)= -0.700231
# differential_evolution step 504: f(x)= -0.700341
# differential_evolution step 505: f(x)= -0.700341
# differential_evolution step 506: f(x)= -0.700341
# differential_evolution step 507: f(x)= -0.700909
# differential_evolution step 508: f(x)= -0.701045
# differential_evolution step 509: f(x)= -0.701045
# differential_evolution step 510: f(x)= -0.701045
# differential_evolution step 511: f(x)= -0.701045
# differential_evolution step 512: f(x)= -0.701045
# differential_evolution step 513: f(x)= -0.701045
# differential_evolution step 514: f(x)= -0.701355
# differential_evolution step 515: f(x)= -0.701355
# differential_evolution step 516: f(x)= -0.701355
# differential_evolution step 517: f(x)= -0.701355
# differential_evolution step 518: f(x)= -0.701355
# differential_evolution step 519: f(x)= -0.701355
# differential_evolution step 520: f(x)= -0.701355
# differential_evolution step 521: f(x)= -0.701355
# differential_evolution step 522: f(x)= -0.701355
# differential_evolution step 523: f(x)= -0.701355
# differential_evolution step 524: f(x)= -0.701355
# differential_evolution step 525: f(x)= -0.701355
# differential_evolution step 526: f(x)= -0.701355
# differential_evolution step 527: f(x)= -0.701355
# differential_evolution step 528: f(x)= -0.701355
# differential_evolution step 529: f(x)= -0.701355
# differential_evolution step 530: f(x)= -0.701355
# differential_evolution step 531: f(x)= -0.701355
# differential_evolution step 532: f(x)= -0.701355
# differential_evolution step 533: f(x)= -0.701355
# differential_evolution step 534: f(x)= -0.701355
# differential_evolution step 535: f(x)= -0.701355
# differential_evolution step 536: f(x)= -0.701355
# differential_evolution step 537: f(x)= -0.701883
# differential_evolution step 538: f(x)= -0.701883
# differential_evolution step 539: f(x)= -0.701883
# differential_evolution step 540: f(x)= -0.701883
# differential_evolution step 541: f(x)= -0.701883
# differential_evolution step 542: f(x)= -0.701883
# differential_evolution step 543: f(x)= -0.702156
# differential_evolution step 544: f(x)= -0.702156
# differential_evolution step 545: f(x)= -0.702156
# differential_evolution step 546: f(x)= -0.702156
# differential_evolution step 547: f(x)= -0.702156
# differential_evolution step 548: f(x)= -0.702156
# differential_evolution step 549: f(x)= -0.702156
# differential_evolution step 550: f(x)= -0.702156
# differential_evolution step 551: f(x)= -0.702156
# differential_evolution step 552: f(x)= -0.702156
# differential_evolution step 553: f(x)= -0.702156
# differential_evolution step 554: f(x)= -0.702156
# differential_evolution step 555: f(x)= -0.702156
# differential_evolution step 556: f(x)= -0.702156
# differential_evolution step 557: f(x)= -0.702156
# differential_evolution step 558: f(x)= -0.702156
# differential_evolution step 559: f(x)= -0.702156
# differential_evolution step 560: f(x)= -0.702156
# differential_evolution step 561: f(x)= -0.702156
# differential_evolution step 562: f(x)= -0.702156
# differential_evolution step 563: f(x)= -0.702156
# differential_evolution step 564: f(x)= -0.702156
# differential_evolution step 565: f(x)= -0.702156
# differential_evolution step 566: f(x)= -0.702569
# differential_evolution step 567: f(x)= -0.702569
# differential_evolution step 568: f(x)= -0.702569
# differential_evolution step 569: f(x)= -0.702569
# differential_evolution step 570: f(x)= -0.702569
# differential_evolution step 571: f(x)= -0.702569
# differential_evolution step 572: f(x)= -0.702569
# differential_evolution step 573: f(x)= -0.702569
# differential_evolution step 574: f(x)= -0.702569
# differential_evolution step 575: f(x)= -0.702569
# differential_evolution step 576: f(x)= -0.702569
# differential_evolution step 577: f(x)= -0.702569
# differential_evolution step 578: f(x)= -0.702569
# differential_evolution step 579: f(x)= -0.702569
# differential_evolution step 580: f(x)= -0.702569
# differential_evolution step 581: f(x)= -0.702569
# differential_evolution step 582: f(x)= -0.702569
# differential_evolution step 583: f(x)= -0.702569
# differential_evolution step 584: f(x)= -0.702569
# differential_evolution step 585: f(x)= -0.702569
# differential_evolution step 586: f(x)= -0.702569
# differential_evolution step 587: f(x)= -0.702569
# differential_evolution step 588: f(x)= -0.702631
# differential_evolution step 589: f(x)= -0.702631
# differential_evolution step 590: f(x)= -0.702986
# differential_evolution step 591: f(x)= -0.703163
# differential_evolution step 592: f(x)= -0.703163
# differential_evolution step 593: f(x)= -0.703163
# differential_evolution step 594: f(x)= -0.703163
# differential_evolution step 595: f(x)= -0.703163
# differential_evolution step 596: f(x)= -0.703163
# differential_evolution step 597: f(x)= -0.703163
# differential_evolution step 598: f(x)= -0.703163
# differential_evolution step 599: f(x)= -0.703163
# differential_evolution step 600: f(x)= -0.703163
# differential_evolution step 601: f(x)= -0.703163
# differential_evolution step 602: f(x)= -0.703163
# differential_evolution step 603: f(x)= -0.703163
# differential_evolution step 604: f(x)= -0.703163
# differential_evolution step 605: f(x)= -0.703163
# differential_evolution step 606: f(x)= -0.703163
# differential_evolution step 607: f(x)= -0.703163
# differential_evolution step 608: f(x)= -0.703163
# differential_evolution step 609: f(x)= -0.703163
# differential_evolution step 610: f(x)= -0.703163
# differential_evolution step 611: f(x)= -0.703163
# differential_evolution step 612: f(x)= -0.703163
# differential_evolution step 613: f(x)= -0.703163
# differential_evolution step 614: f(x)= -0.703163
# differential_evolution step 615: f(x)= -0.703163
# differential_evolution step 616: f(x)= -0.703163
# differential_evolution step 617: f(x)= -0.703163
# differential_evolution step 618: f(x)= -0.703163
# differential_evolution step 619: f(x)= -0.703258
# differential_evolution step 620: f(x)= -0.703623
# differential_evolution step 621: f(x)= -0.703623
# differential_evolution step 622: f(x)= -0.703933
# differential_evolution step 623: f(x)= -0.703933
# differential_evolution step 624: f(x)= -0.703933
# differential_evolution step 625: f(x)= -0.703933
# differential_evolution step 626: f(x)= -0.703933
# differential_evolution step 627: f(x)= -0.703933
# differential_evolution step 628: f(x)= -0.703933
# differential_evolution step 629: f(x)= -0.703933
# differential_evolution step 630: f(x)= -0.703933
# differential_evolution step 631: f(x)= -0.703933
# differential_evolution step 632: f(x)= -0.703933
# differential_evolution step 633: f(x)= -0.703933
# differential_evolution step 634: f(x)= -0.703933
# differential_evolution step 635: f(x)= -0.703933
# differential_evolution step 636: f(x)= -0.704097
# differential_evolution step 637: f(x)= -0.704097
# differential_evolution step 638: f(x)= -0.704097
# differential_evolution step 639: f(x)= -0.704097
# differential_evolution step 640: f(x)= -0.704097
# differential_evolution step 641: f(x)= -0.704097
# differential_evolution step 642: f(x)= -0.704097
# differential_evolution step 643: f(x)= -0.704097
# differential_evolution step 644: f(x)= -0.704097
# differential_evolution step 645: f(x)= -0.704097
# differential_evolution step 646: f(x)= -0.704097
# differential_evolution step 647: f(x)= -0.704097
# differential_evolution step 648: f(x)= -0.704097
# differential_evolution step 649: f(x)= -0.704097
# differential_evolution step 650: f(x)= -0.704097
# differential_evolution step 651: f(x)= -0.704097
# differential_evolution step 652: f(x)= -0.704097
# differential_evolution step 653: f(x)= -0.704097
# differential_evolution step 654: f(x)= -0.704097
# differential_evolution step 655: f(x)= -0.704097
# differential_evolution step 656: f(x)= -0.704097
# differential_evolution step 657: f(x)= -0.704097
# differential_evolution step 658: f(x)= -0.704097
# differential_evolution step 659: f(x)= -0.704097
# differential_evolution step 660: f(x)= -0.704224
# differential_evolution step 661: f(x)= -0.704224
# differential_evolution step 662: f(x)= -0.704466
# differential_evolution step 663: f(x)= -0.704466
# differential_evolution step 664: f(x)= -0.704466
# differential_evolution step 665: f(x)= -0.704466
# differential_evolution step 666: f(x)= -0.704466
# differential_evolution step 667: f(x)= -0.704466
# differential_evolution step 668: f(x)= -0.704466
# differential_evolution step 669: f(x)= -0.704466
# differential_evolution step 670: f(x)= -0.704466
# differential_evolution step 671: f(x)= -0.704661
# differential_evolution step 672: f(x)= -0.704661
# differential_evolution step 673: f(x)= -0.704661
# differential_evolution step 674: f(x)= -0.704661
# differential_evolution step 675: f(x)= -0.704697
# differential_evolution step 676: f(x)= -0.705051
# differential_evolution step 677: f(x)= -0.705099
# differential_evolution step 678: f(x)= -0.705158
# differential_evolution step 679: f(x)= -0.705158
# differential_evolution step 680: f(x)= -0.705158
# differential_evolution step 681: f(x)= -0.705158
# differential_evolution step 682: f(x)= -0.705158
# differential_evolution step 683: f(x)= -0.705158
# differential_evolution step 684: f(x)= -0.705158
# differential_evolution step 685: f(x)= -0.705158
# differential_evolution step 686: f(x)= -0.705158
# differential_evolution step 687: f(x)= -0.705158
# differential_evolution step 688: f(x)= -0.705158
# differential_evolution step 689: f(x)= -0.705158
# differential_evolution step 690: f(x)= -0.705411
# differential_evolution step 691: f(x)= -0.705411
# differential_evolution step 692: f(x)= -0.705411
# differential_evolution step 693: f(x)= -0.705411
# differential_evolution step 694: f(x)= -0.705411
# differential_evolution step 695: f(x)= -0.705411
# differential_evolution step 696: f(x)= -0.705411
# differential_evolution step 697: f(x)= -0.705559
# differential_evolution step 698: f(x)= -0.705559
# differential_evolution step 699: f(x)= -0.705559
# differential_evolution step 700: f(x)= -0.705559
# differential_evolution step 701: f(x)= -0.705823
# differential_evolution step 702: f(x)= -0.705823
# differential_evolution step 703: f(x)= -0.705911
# differential_evolution step 704: f(x)= -0.705911
# differential_evolution step 705: f(x)= -0.705911
# differential_evolution step 706: f(x)= -0.705911
# differential_evolution step 707: f(x)= -0.705911
# differential_evolution step 708: f(x)= -0.705911
# differential_evolution step 709: f(x)= -0.705911
# differential_evolution step 710: f(x)= -0.705911
# differential_evolution step 711: f(x)= -0.705911
# differential_evolution step 712: f(x)= -0.705911
# differential_evolution step 713: f(x)= -0.705911
# differential_evolution step 714: f(x)= -0.705911
# differential_evolution step 715: f(x)= -0.705911
# differential_evolution step 716: f(x)= -0.705911
# differential_evolution step 717: f(x)= -0.705911
# differential_evolution step 718: f(x)= -0.706209
# differential_evolution step 719: f(x)= -0.706209
# differential_evolution step 720: f(x)= -0.706209
# differential_evolution step 721: f(x)= -0.706209
# differential_evolution step 722: f(x)= -0.706209
# differential_evolution step 723: f(x)= -0.706209
# differential_evolution step 724: f(x)= -0.706209
# differential_evolution step 725: f(x)= -0.706209
# differential_evolution step 726: f(x)= -0.706209
# differential_evolution step 727: f(x)= -0.706209
# differential_evolution step 728: f(x)= -0.706209
# differential_evolution step 729: f(x)= -0.706209
# differential_evolution step 730: f(x)= -0.706209
# differential_evolution step 731: f(x)= -0.706209
# differential_evolution step 732: f(x)= -0.706209
# differential_evolution step 733: f(x)= -0.706209
# differential_evolution step 734: f(x)= -0.706209
# differential_evolution step 735: f(x)= -0.706209
# differential_evolution step 736: f(x)= -0.706209
# differential_evolution step 737: f(x)= -0.706209
# differential_evolution step 738: f(x)= -0.706209
# differential_evolution step 739: f(x)= -0.706209
# differential_evolution step 740: f(x)= -0.706209
# differential_evolution step 741: f(x)= -0.706209
# differential_evolution step 742: f(x)= -0.706209
# differential_evolution step 743: f(x)= -0.706209
# differential_evolution step 744: f(x)= -0.706209
# differential_evolution step 745: f(x)= -0.706209
# differential_evolution step 746: f(x)= -0.706209
# differential_evolution step 747: f(x)= -0.706209
# differential_evolution step 748: f(x)= -0.706209
# differential_evolution step 749: f(x)= -0.706209
# differential_evolution step 750: f(x)= -0.706209
# -0.7062089885323558 [0.78770498 0.99670739 0.50769769 0.80101781 0.81479184 0.51020115
#  0.99127041 0.62121103 0.68610984 0.10290845 0.37639467 0.04601872
#  0.05038175 0.0355167  0.00498837 0.28306717 0.04525175 0.06378879
#  0.05739769 0.01399965 0.02608653 0.00841348 0.0644189  0.05911348
#  0.03842901 0.03849918 0.06130318 0.28019713 0.25759398 0.46160488
#  0.94154512 0.68398619 0.59161183 0.43124393 0.48459284 0.39143535
#  0.42054128 0.01928061 0.66112264 0.80935657 0.57136525 0.4783573
#  0.31570318 0.16007769 0.39999082 0.59934638 0.59089884 0.15220614
#  0.56010003 0.82398991 0.04324269 0.42488136 0.10826435 0.53616858
#  0.33468297 0.45567875 0.45504776 0.41856376 0.30597121 0.50576318
#  0.42556707 0.55904369 0.65055605 0.35486518 0.74235477 0.87148285
#  0.79731297 0.95461844 0.9685507  0.41584307 0.63905876 0.43595718
#  0.83059724 0.56260432 0.30912256 0.2934813  0.03974638 0.34873274
#  0.3618286  0.29344954 0.20458845 0.0491729  0.40480306 0.15958831
#  0.14883051 0.14319445 0.40778578 0.19036198 0.49854233 0.72991835
#  0.63678193 0.91370514 0.75180068 0.49810412 0.21240565 0.70283045
#  0.41021364 0.34779941 0.49191463 0.65613799 0.80887296 0.48298908
#  0.60371137 0.73707417 0.20498285 0.2883657  0.59968746 0.55136358
#  0.09628219 0.30057636 0.31589442 0.34560165 0.00436658 0.3346128
#  0.47121147 0.52262151 0.35833814 0.34055067 0.20803469 0.57680015
#  0.13993992 0.07481143 0.14878103 0.32488276 0.40382489 0.86640272
#  0.65166163 0.41454104 0.33601204 0.16463269 0.48475513 0.73832919
#  0.35721072 0.65495639 0.55694808 0.76678984 0.10402727 0.15766153
#  0.21749237 0.58419546 0.12729348 0.49653324 0.59051573 0.40526257
#  0.39928505 0.56994421 0.4898579  0.77806294 0.72025228 0.74719447
#  0.60904555 0.80369393 0.9055364  0.93852446 0.45935539 0.96886818
#  0.57698526 0.64878424 0.90940681 0.77889497 0.67661635 0.64644716
#  0.60645912 0.47588092 0.70737097 0.68084024 0.14697797 0.46644939
#  0.29252135 0.59724722 0.1948962  0.22461591 0.08402677 0.18273174
#  0.2315915  0.25770561 0.26620577 0.10300681 0.24821092 0.03079955
#  0.01179966 0.15263013 0.20502675 0.13974296 0.07858283 0.022232
#  0.16006086 0.23925392 0.6971236  0.34521435 0.61965315 0.16384569
#  0.42919694 0.44905683 0.43940783 0.35974231 0.58146885 0.3602557
#  0.29598725 0.61045737 0.53563827 0.50675456 0.42438066 0.54393409
#  0.48921964 0.15598287 0.62892031 0.52180524 0.72565847 0.49153042
#  0.64650633 0.62898744 0.73712585 0.52898299 0.7187425  0.44394485
#  0.78218362 0.98659439 0.9490089  0.79062841 0.79149116 0.6716799
#  0.83527874 0.48418001 0.51177881 0.5415622  0.66805206 0.02533032
#  0.21599369 0.6394111  0.10623513 0.5531158  0.05085424 0.00632997
#  0.00655985 0.24155961 0.04237559 0.0698716  0.17086078 0.13040152
#  0.06832293 0.10990977 0.06998785 0.39803969 0.178907   0.32287174
#  0.17048611 0.22177699 0.08959286 0.47782724 0.63765811 0.71955228
#  0.64927592 0.23910453 0.38553297 0.72283233 0.63177087 0.72376705
#  0.63444084 0.51547559 0.38730747 0.21401895 0.37838869 0.68086335
#  0.66752174 0.59063941 0.45517081 0.35545094 0.13846276 0.57303088
#  0.57786252 0.55469202 0.58612703 0.50005917 0.39252535 0.6587706
#  0.16534176 0.59235091 0.48996195 0.87298161 0.91244358 0.87557384
#  0.73011511 0.74620613 0.71358943 0.73132613 0.41345076 0.38597476
#  0.0870748  0.01431089 0.21790841 0.0182068  0.24292216 0.17150383
#  0.04040169 0.12399081 0.08992238 0.02534294 0.04932062 0.0149889
#  0.14467646 0.22258416 0.03693055 0.06401332 0.05096733 0.03489988
#  0.09870662 0.37979623 0.55376362 0.83079697]
# case: 1 (base reward: -0.58)
# differential_evolution step 1: f(x)= -0.598752
# differential_evolution step 2: f(x)= -0.602551
# differential_evolution step 3: f(x)= -0.609651
# differential_evolution step 4: f(x)= -0.609792
# differential_evolution step 5: f(x)= -0.609792
# differential_evolution step 6: f(x)= -0.609792
# differential_evolution step 7: f(x)= -0.609792
# differential_evolution step 8: f(x)= -0.609792
# differential_evolution step 9: f(x)= -0.609956
# differential_evolution step 10: f(x)= -0.610927
# differential_evolution step 11: f(x)= -0.610927
# differential_evolution step 12: f(x)= -0.614597
# differential_evolution step 13: f(x)= -0.614597
# differential_evolution step 14: f(x)= -0.616234
# differential_evolution step 15: f(x)= -0.616234
# differential_evolution step 16: f(x)= -0.616234
# differential_evolution step 17: f(x)= -0.616234
# differential_evolution step 18: f(x)= -0.616234
# differential_evolution step 19: f(x)= -0.617964
# differential_evolution step 20: f(x)= -0.617964
# differential_evolution step 21: f(x)= -0.617964
# differential_evolution step 22: f(x)= -0.617964
# differential_evolution step 23: f(x)= -0.617964
# differential_evolution step 24: f(x)= -0.617964
# differential_evolution step 25: f(x)= -0.617964
# differential_evolution step 26: f(x)= -0.617964
# differential_evolution step 27: f(x)= -0.617964
# differential_evolution step 28: f(x)= -0.617964
# differential_evolution step 29: f(x)= -0.617964
# differential_evolution step 30: f(x)= -0.617964
# differential_evolution step 31: f(x)= -0.619191
# differential_evolution step 32: f(x)= -0.619191
# differential_evolution step 33: f(x)= -0.619191
# differential_evolution step 34: f(x)= -0.619191
# differential_evolution step 35: f(x)= -0.619191
# differential_evolution step 36: f(x)= -0.619191
# differential_evolution step 37: f(x)= -0.624635
# differential_evolution step 38: f(x)= -0.624635
# differential_evolution step 39: f(x)= -0.627077
# differential_evolution step 40: f(x)= -0.627077
# differential_evolution step 41: f(x)= -0.627077
# differential_evolution step 42: f(x)= -0.627077
# differential_evolution step 43: f(x)= -0.627077
# differential_evolution step 44: f(x)= -0.627077
# differential_evolution step 45: f(x)= -0.627077
# differential_evolution step 46: f(x)= -0.627077
# differential_evolution step 47: f(x)= -0.627896
# differential_evolution step 48: f(x)= -0.631577
# differential_evolution step 49: f(x)= -0.631577
# differential_evolution step 50: f(x)= -0.631577
# differential_evolution step 51: f(x)= -0.631577
# differential_evolution step 52: f(x)= -0.631577
# differential_evolution step 53: f(x)= -0.631577
# differential_evolution step 54: f(x)= -0.631577
# differential_evolution step 55: f(x)= -0.631577
# differential_evolution step 56: f(x)= -0.631577
# differential_evolution step 57: f(x)= -0.631577
# differential_evolution step 58: f(x)= -0.631577
# differential_evolution step 59: f(x)= -0.631577
# differential_evolution step 60: f(x)= -0.631577
# differential_evolution step 61: f(x)= -0.631577
# differential_evolution step 62: f(x)= -0.631577
# differential_evolution step 63: f(x)= -0.631577
# differential_evolution step 64: f(x)= -0.631577
# differential_evolution step 65: f(x)= -0.632476
# differential_evolution step 66: f(x)= -0.632476
# differential_evolution step 67: f(x)= -0.632476
# differential_evolution step 68: f(x)= -0.632476
# differential_evolution step 69: f(x)= -0.632476
# differential_evolution step 70: f(x)= -0.632476
# differential_evolution step 71: f(x)= -0.632476
# differential_evolution step 72: f(x)= -0.632476
# differential_evolution step 73: f(x)= -0.632476
# differential_evolution step 74: f(x)= -0.634051
# differential_evolution step 75: f(x)= -0.636504
# differential_evolution step 76: f(x)= -0.636504
# differential_evolution step 77: f(x)= -0.636757
# differential_evolution step 78: f(x)= -0.636757
# differential_evolution step 79: f(x)= -0.636757
# differential_evolution step 80: f(x)= -0.636757
# differential_evolution step 81: f(x)= -0.636757
# differential_evolution step 82: f(x)= -0.637677
# differential_evolution step 83: f(x)= -0.637677
# differential_evolution step 84: f(x)= -0.637677
# differential_evolution step 85: f(x)= -0.637677
# differential_evolution step 86: f(x)= -0.637677
# differential_evolution step 87: f(x)= -0.637677
# differential_evolution step 88: f(x)= -0.637677
# differential_evolution step 89: f(x)= -0.637677
# differential_evolution step 90: f(x)= -0.637677
# differential_evolution step 91: f(x)= -0.637677
# differential_evolution step 92: f(x)= -0.637677
# differential_evolution step 93: f(x)= -0.637677
# differential_evolution step 94: f(x)= -0.639147
# differential_evolution step 95: f(x)= -0.639147
# differential_evolution step 96: f(x)= -0.639147
# differential_evolution step 97: f(x)= -0.639147
# differential_evolution step 98: f(x)= -0.63947
# differential_evolution step 99: f(x)= -0.639671
# differential_evolution step 100: f(x)= -0.639671
# differential_evolution step 101: f(x)= -0.639671
# differential_evolution step 102: f(x)= -0.64076
# differential_evolution step 103: f(x)= -0.64076
# differential_evolution step 104: f(x)= -0.64076
# differential_evolution step 105: f(x)= -0.64076
# differential_evolution step 106: f(x)= -0.64076
# differential_evolution step 107: f(x)= -0.64076
# differential_evolution step 108: f(x)= -0.64076
# differential_evolution step 109: f(x)= -0.64076
# differential_evolution step 110: f(x)= -0.64076
# differential_evolution step 111: f(x)= -0.64076
# differential_evolution step 112: f(x)= -0.643192
# differential_evolution step 113: f(x)= -0.643192
# differential_evolution step 114: f(x)= -0.643192
# differential_evolution step 115: f(x)= -0.643192
# differential_evolution step 116: f(x)= -0.643192
# differential_evolution step 117: f(x)= -0.643721
# differential_evolution step 118: f(x)= -0.643721
# differential_evolution step 119: f(x)= -0.644418
# differential_evolution step 120: f(x)= -0.644418
# differential_evolution step 121: f(x)= -0.644418
# differential_evolution step 122: f(x)= -0.645858
# differential_evolution step 123: f(x)= -0.645858
# differential_evolution step 124: f(x)= -0.645858
# differential_evolution step 125: f(x)= -0.645858
# differential_evolution step 126: f(x)= -0.645858
# differential_evolution step 127: f(x)= -0.645858
# differential_evolution step 128: f(x)= -0.645858
# differential_evolution step 129: f(x)= -0.645858
# differential_evolution step 130: f(x)= -0.645858
# differential_evolution step 131: f(x)= -0.645858
# differential_evolution step 132: f(x)= -0.645858
# differential_evolution step 133: f(x)= -0.645858
# differential_evolution step 134: f(x)= -0.645858
# differential_evolution step 135: f(x)= -0.645858
# differential_evolution step 136: f(x)= -0.645858
# differential_evolution step 137: f(x)= -0.645858
# differential_evolution step 138: f(x)= -0.645858
# differential_evolution step 139: f(x)= -0.645858
# differential_evolution step 140: f(x)= -0.647191
# differential_evolution step 141: f(x)= -0.647191
# differential_evolution step 142: f(x)= -0.647191
# differential_evolution step 143: f(x)= -0.647191
# differential_evolution step 144: f(x)= -0.647191
# differential_evolution step 145: f(x)= -0.647191
# differential_evolution step 146: f(x)= -0.647191
# differential_evolution step 147: f(x)= -0.647721
# differential_evolution step 148: f(x)= -0.649718
# differential_evolution step 149: f(x)= -0.649718
# differential_evolution step 150: f(x)= -0.649718
# differential_evolution step 151: f(x)= -0.649718
# differential_evolution step 152: f(x)= -0.649718
# differential_evolution step 153: f(x)= -0.649718
# differential_evolution step 154: f(x)= -0.649718
# differential_evolution step 155: f(x)= -0.649718
# differential_evolution step 156: f(x)= -0.649718
# differential_evolution step 157: f(x)= -0.649718
# differential_evolution step 158: f(x)= -0.649718
# differential_evolution step 159: f(x)= -0.649718
# differential_evolution step 160: f(x)= -0.649718
# differential_evolution step 161: f(x)= -0.649718
# differential_evolution step 162: f(x)= -0.649718
# differential_evolution step 163: f(x)= -0.649718
# ...
# differential_evolution step 170: f(x)= -0.656955
# differential_evolution step 171: f(x)= -0.656955
# differential_evolution step 172: f(x)= -0.656955
# differential_evolution step 173: f(x)= -0.656955
# differential_evolution step 174: f(x)= -0.656955
# differential_evolution step 175: f(x)= -0.656955
# differential_evolution step 176: f(x)= -0.657707
# differential_evolution step 177: f(x)= -0.658047
# differential_evolution step 178: f(x)= -0.658047
# differential_evolution step 179: f(x)= -0.658047
# differential_evolution step 180: f(x)= -0.658047
# differential_evolution step 181: f(x)= -0.658047
# differential_evolution step 182: f(x)= -0.658047
# differential_evolution step 183: f(x)= -0.658986
# differential_evolution step 184: f(x)= -0.658986
# differential_evolution step 185: f(x)= -0.658986
# differential_evolution step 186: f(x)= -0.658986
# differential_evolution step 187: f(x)= -0.658986
# differential_evolution step 188: f(x)= -0.658986
# differential_evolution step 189: f(x)= -0.658986
# differential_evolution step 190: f(x)= -0.658986
# differential_evolution step 191: f(x)= -0.659393
# differential_evolution step 192: f(x)= -0.659393
# differential_evolution step 193: f(x)= -0.661088
# differential_evolution step 194: f(x)= -0.661088
# differential_evolution step 195: f(x)= -0.661088
# differential_evolution step 196: f(x)= -0.661236
# differential_evolution step 197: f(x)= -0.661236
# differential_evolution step 198: f(x)= -0.661236
# differential_evolution step 199: f(x)= -0.661236
# differential_evolution step 200: f(x)= -0.661236
# differential_evolution step 201: f(x)= -0.661236
# differential_evolution step 202: f(x)= -0.662605
# differential_evolution step 203: f(x)= -0.662605
# differential_evolution step 204: f(x)= -0.662605
# differential_evolution step 205: f(x)= -0.662605
# differential_evolution step 206: f(x)= -0.662605
# differential_evolution step 207: f(x)= -0.662605
# differential_evolution step 208: f(x)= -0.662605
# differential_evolution step 209: f(x)= -0.662605
# differential_evolution step 210: f(x)= -0.662605
# differential_evolution step 211: f(x)= -0.663083
# differential_evolution step 212: f(x)= -0.663083
# differential_evolution step 213: f(x)= -0.663083
# differential_evolution step 214: f(x)= -0.663083
# differential_evolution step 215: f(x)= -0.663083
# differential_evolution step 216: f(x)= -0.663083
# differential_evolution step 217: f(x)= -0.663083
# differential_evolution step 218: f(x)= -0.663083
# differential_evolution step 219: f(x)= -0.663083
# differential_evolution step 220: f(x)= -0.663083
# differential_evolution step 221: f(x)= -0.663083
# differential_evolution step 222: f(x)= -0.663083
# differential_evolution step 223: f(x)= -0.663083
# differential_evolution step 224: f(x)= -0.663083
# differential_evolution step 225: f(x)= -0.663083
# differential_evolution step 226: f(x)= -0.663083
# differential_evolution step 227: f(x)= -0.663083
# differential_evolution step 228: f(x)= -0.663083
# differential_evolution step 229: f(x)= -0.66397
# differential_evolution step 230: f(x)= -0.66397
# differential_evolution step 231: f(x)= -0.66397
# differential_evolution step 232: f(x)= -0.666152
# differential_evolution step 233: f(x)= -0.666152
# differential_evolution step 234: f(x)= -0.666152
# differential_evolution step 235: f(x)= -0.666152
# differential_evolution step 236: f(x)= -0.666152
# differential_evolution step 237: f(x)= -0.666152
# differential_evolution step 238: f(x)= -0.666152
# differential_evolution step 239: f(x)= -0.666152
# differential_evolution step 240: f(x)= -0.666152
# differential_evolution step 241: f(x)= -0.66642
# differential_evolution step 242: f(x)= -0.66642
# differential_evolution step 243: f(x)= -0.666647
# differential_evolution step 244: f(x)= -0.666647
# differential_evolution step 245: f(x)= -0.666647
# differential_evolution step 246: f(x)= -0.666647
# differential_evolution step 247: f(x)= -0.666647
# differential_evolution step 248: f(x)= -0.667064
# differential_evolution step 249: f(x)= -0.667064
# differential_evolution step 250: f(x)= -0.667064
# differential_evolution step 251: f(x)= -0.667723
# differential_evolution step 252: f(x)= -0.667723
# differential_evolution step 253: f(x)= -0.667723
# differential_evolution step 254: f(x)= -0.667723
# differential_evolution step 255: f(x)= -0.667723
# differential_evolution step 256: f(x)= -0.668114
# differential_evolution step 257: f(x)= -0.668114
# differential_evolution step 258: f(x)= -0.668114
# differential_evolution step 259: f(x)= -0.668114
# differential_evolution step 260: f(x)= -0.668114
# differential_evolution step 261: f(x)= -0.668114
# differential_evolution step 262: f(x)= -0.668114
# differential_evolution step 263: f(x)= -0.668114
# differential_evolution step 264: f(x)= -0.668114
# differential_evolution step 265: f(x)= -0.668731
# differential_evolution step 266: f(x)= -0.669547
# differential_evolution step 267: f(x)= -0.669547
# differential_evolution step 268: f(x)= -0.670589
# differential_evolution step 269: f(x)= -0.670589
# differential_evolution step 270: f(x)= -0.670589
# differential_evolution step 271: f(x)= -0.670932
# differential_evolution step 272: f(x)= -0.670932
# differential_evolution step 273: f(x)= -0.670932
# differential_evolution step 274: f(x)= -0.670932
# differential_evolution step 275: f(x)= -0.673595
# differential_evolution step 276: f(x)= -0.673595
# differential_evolution step 277: f(x)= -0.673595
# differential_evolution step 278: f(x)= -0.673595
# differential_evolution step 279: f(x)= -0.673595
# differential_evolution step 280: f(x)= -0.673595
# differential_evolution step 281: f(x)= -0.673595
# differential_evolution step 282: f(x)= -0.673595
# differential_evolution step 283: f(x)= -0.673595
# differential_evolution step 284: f(x)= -0.673595
# differential_evolution step 285: f(x)= -0.673595
# differential_evolution step 286: f(x)= -0.673595
# differential_evolution step 287: f(x)= -0.673595
# differential_evolution step 288: f(x)= -0.673595
# differential_evolution step 289: f(x)= -0.673595
# differential_evolution step 290: f(x)= -0.673595
# differential_evolution step 291: f(x)= -0.673831
# differential_evolution step 292: f(x)= -0.67415
# differential_evolution step 293: f(x)= -0.67415
# differential_evolution step 294: f(x)= -0.67415
# differential_evolution step 295: f(x)= -0.67415
# differential_evolution step 296: f(x)= -0.675076
# differential_evolution step 297: f(x)= -0.675767
# differential_evolution step 298: f(x)= -0.675767
# differential_evolution step 299: f(x)= -0.675767
# differential_evolution step 300: f(x)= -0.675767
# differential_evolution step 301: f(x)= -0.675767
# differential_evolution step 302: f(x)= -0.675767
# differential_evolution step 303: f(x)= -0.675767
# differential_evolution step 304: f(x)= -0.675767
# differential_evolution step 305: f(x)= -0.675767
# differential_evolution step 306: f(x)= -0.675767
# differential_evolution step 307: f(x)= -0.675767
# differential_evolution step 308: f(x)= -0.675767
# differential_evolution step 309: f(x)= -0.675767
# differential_evolution step 310: f(x)= -0.675767
# differential_evolution step 311: f(x)= -0.675767
# differential_evolution step 312: f(x)= -0.675767
# differential_evolution step 313: f(x)= -0.675767
# differential_evolution step 314: f(x)= -0.675767
# differential_evolution step 315: f(x)= -0.675767
# differential_evolution step 316: f(x)= -0.675767
# differential_evolution step 317: f(x)= -0.675767
# differential_evolution step 318: f(x)= -0.675767
# differential_evolution step 319: f(x)= -0.676142
# differential_evolution step 320: f(x)= -0.676142
# differential_evolution step 321: f(x)= -0.676142
# differential_evolution step 322: f(x)= -0.676142
# differential_evolution step 323: f(x)= -0.676142
# differential_evolution step 324: f(x)= -0.676142
# differential_evolution step 325: f(x)= -0.676142
# differential_evolution step 326: f(x)= -0.676142
# differential_evolution step 327: f(x)= -0.676142
# differential_evolution step 328: f(x)= -0.676142
# differential_evolution step 329: f(x)= -0.676347
# differential_evolution step 330: f(x)= -0.676347
# differential_evolution step 331: f(x)= -0.676347
# differential_evolution step 332: f(x)= -0.676347
# differential_evolution step 333: f(x)= -0.676347
# differential_evolution step 334: f(x)= -0.676347
# differential_evolution step 335: f(x)= -0.676347
# differential_evolution step 336: f(x)= -0.676347
# differential_evolution step 337: f(x)= -0.676347
# differential_evolution step 338: f(x)= -0.676347
# differential_evolution step 339: f(x)= -0.676347
# differential_evolution step 340: f(x)= -0.676347
# differential_evolution step 341: f(x)= -0.676347
# differential_evolution step 342: f(x)= -0.676347
# differential_evolution step 343: f(x)= -0.676347
# differential_evolution step 344: f(x)= -0.676347
# differential_evolution step 345: f(x)= -0.676347
# differential_evolution step 346: f(x)= -0.676555
# differential_evolution step 347: f(x)= -0.676555
# differential_evolution step 348: f(x)= -0.676555
# differential_evolution step 349: f(x)= -0.676739
# differential_evolution step 350: f(x)= -0.676739
# differential_evolution step 351: f(x)= -0.677991
# differential_evolution step 352: f(x)= -0.677991
# differential_evolution step 353: f(x)= -0.677991
# differential_evolution step 354: f(x)= -0.677991
# differential_evolution step 355: f(x)= -0.677991
# differential_evolution step 356: f(x)= -0.677991
# differential_evolution step 357: f(x)= -0.677991
# differential_evolution step 358: f(x)= -0.677991
# differential_evolution step 359: f(x)= -0.678189
# differential_evolution step 360: f(x)= -0.678718
# differential_evolution step 361: f(x)= -0.678718
# differential_evolution step 362: f(x)= -0.678718
# differential_evolution step 363: f(x)= -0.678718
# differential_evolution step 364: f(x)= -0.678718
# differential_evolution step 365: f(x)= -0.678718
# differential_evolution step 366: f(x)= -0.678718
# differential_evolution step 367: f(x)= -0.678718
# differential_evolution step 368: f(x)= -0.678718
# differential_evolution step 369: f(x)= -0.678718
# differential_evolution step 370: f(x)= -0.678718
# differential_evolution step 371: f(x)= -0.678718
# differential_evolution step 372: f(x)= -0.678718
# differential_evolution step 373: f(x)= -0.678718
# differential_evolution step 374: f(x)= -0.678718
# differential_evolution step 375: f(x)= -0.678718
# differential_evolution step 376: f(x)= -0.679815
# differential_evolution step 377: f(x)= -0.679815
# differential_evolution step 378: f(x)= -0.679815
# differential_evolution step 379: f(x)= -0.679815
# differential_evolution step 380: f(x)= -0.679815
# differential_evolution step 381: f(x)= -0.679815
# differential_evolution step 382: f(x)= -0.679815
# differential_evolution step 383: f(x)= -0.679815
# differential_evolution step 384: f(x)= -0.679815
# differential_evolution step 385: f(x)= -0.679815
# differential_evolution step 386: f(x)= -0.679815
# differential_evolution step 387: f(x)= -0.679815
# differential_evolution step 388: f(x)= -0.679986
# differential_evolution step 389: f(x)= -0.679986
# differential_evolution step 390: f(x)= -0.679986
# differential_evolution step 391: f(x)= -0.679986
# differential_evolution step 392: f(x)= -0.679986
# differential_evolution step 393: f(x)= -0.680239
# differential_evolution step 394: f(x)= -0.680239
# differential_evolution step 395: f(x)= -0.680239
# differential_evolution step 396: f(x)= -0.680239
# differential_evolution step 397: f(x)= -0.680239
# differential_evolution step 398: f(x)= -0.680239
# differential_evolution step 399: f(x)= -0.680239
# differential_evolution step 400: f(x)= -0.680239
# differential_evolution step 401: f(x)= -0.681226
# differential_evolution step 402: f(x)= -0.681563
# differential_evolution step 403: f(x)= -0.681563
# differential_evolution step 404: f(x)= -0.681563
# differential_evolution step 405: f(x)= -0.681563
# differential_evolution step 406: f(x)= -0.681563
# differential_evolution step 407: f(x)= -0.681563
# differential_evolution step 408: f(x)= -0.681563
# differential_evolution step 409: f(x)= -0.681563
# differential_evolution step 410: f(x)= -0.681928
# differential_evolution step 411: f(x)= -0.681928
# differential_evolution step 412: f(x)= -0.681928
# differential_evolution step 413: f(x)= -0.681928
# differential_evolution step 414: f(x)= -0.681928
# differential_evolution step 415: f(x)= -0.681928
# differential_evolution step 416: f(x)= -0.681928
# differential_evolution step 417: f(x)= -0.681928
# differential_evolution step 418: f(x)= -0.681928
# differential_evolution step 419: f(x)= -0.681928
# differential_evolution step 420: f(x)= -0.681928
# differential_evolution step 421: f(x)= -0.681928
# differential_evolution step 422: f(x)= -0.681928
# differential_evolution step 423: f(x)= -0.681928
# differential_evolution step 424: f(x)= -0.681928
# differential_evolution step 425: f(x)= -0.681928
# differential_evolution step 426: f(x)= -0.681928
# differential_evolution step 427: f(x)= -0.681928
# differential_evolution step 428: f(x)= -0.681928
# differential_evolution step 429: f(x)= -0.681928
# differential_evolution step 430: f(x)= -0.681928
# differential_evolution step 431: f(x)= -0.681928
# differential_evolution step 432: f(x)= -0.682321
# differential_evolution step 433: f(x)= -0.683197
# differential_evolution step 434: f(x)= -0.683197
# differential_evolution step 435: f(x)= -0.683197
# differential_evolution step 436: f(x)= -0.683197
# differential_evolution step 437: f(x)= -0.683197
# differential_evolution step 438: f(x)= -0.683197
# differential_evolution step 439: f(x)= -0.683197
# differential_evolution step 440: f(x)= -0.683197
# differential_evolution step 441: f(x)= -0.683197
# differential_evolution step 442: f(x)= -0.683197
# differential_evolution step 443: f(x)= -0.683197
# differential_evolution step 444: f(x)= -0.683197
# differential_evolution step 445: f(x)= -0.683197
# differential_evolution step 446: f(x)= -0.683197
# differential_evolution step 447: f(x)= -0.683504
# differential_evolution step 448: f(x)= -0.683504
# differential_evolution step 449: f(x)= -0.683504
# differential_evolution step 450: f(x)= -0.683504
# differential_evolution step 451: f(x)= -0.683941
# differential_evolution step 452: f(x)= -0.683941
# differential_evolution step 453: f(x)= -0.683941
# differential_evolution step 454: f(x)= -0.683941
# differential_evolution step 455: f(x)= -0.683941
# differential_evolution step 456: f(x)= -0.683941
# differential_evolution step 457: f(x)= -0.683941
# differential_evolution step 458: f(x)= -0.684683
# differential_evolution step 459: f(x)= -0.684683
# differential_evolution step 460: f(x)= -0.684683
# differential_evolution step 461: f(x)= -0.684683
# differential_evolution step 462: f(x)= -0.684683
# differential_evolution step 463: f(x)= -0.684683
# differential_evolution step 464: f(x)= -0.684683
# differential_evolution step 465: f(x)= -0.684683
# differential_evolution step 466: f(x)= -0.684683
# differential_evolution step 467: f(x)= -0.685259
# differential_evolution step 468: f(x)= -0.685259
# differential_evolution step 469: f(x)= -0.685259
# differential_evolution step 470: f(x)= -0.685259
# differential_evolution step 471: f(x)= -0.685938
# differential_evolution step 472: f(x)= -0.685938
# differential_evolution step 473: f(x)= -0.685938
# differential_evolution step 474: f(x)= -0.685938
# differential_evolution step 475: f(x)= -0.685938
# differential_evolution step 476: f(x)= -0.685938
# differential_evolution step 477: f(x)= -0.685938
# differential_evolution step 478: f(x)= -0.685938
# differential_evolution step 479: f(x)= -0.685938
# differential_evolution step 480: f(x)= -0.685938
# differential_evolution step 481: f(x)= -0.685938
# differential_evolution step 482: f(x)= -0.685938
# differential_evolution step 483: f(x)= -0.685938
# differential_evolution step 484: f(x)= -0.685938
# differential_evolution step 485: f(x)= -0.685938
# differential_evolution step 486: f(x)= -0.685938
# differential_evolution step 487: f(x)= -0.685938
# differential_evolution step 488: f(x)= -0.685938
# differential_evolution step 489: f(x)= -0.685938
# differential_evolution step 490: f(x)= -0.685938
# differential_evolution step 491: f(x)= -0.685938
# differential_evolution step 492: f(x)= -0.685938
# differential_evolution step 493: f(x)= -0.685982
# differential_evolution step 494: f(x)= -0.685982
# differential_evolution step 495: f(x)= -0.685982
