# %%
# to access functions from root directory
import sys
sys.path.append('/data/ad181/RemoteDir/ada_multigrid_ppo')

# %%
# %matplotlib notebook
import numpy as np
import time
import pickle
import os
import matplotlib.pyplot as plt
from copy import copy, deepcopy

import gym
from stable_baselines3.ppo import PPO, MlpPolicy
from stable_baselines3.common.vec_env import SubprocVecEnv, DummyVecEnv
from stable_baselines3.common.callbacks import CallbackList
from utils.custom_eval_callback import CustomEvalCallback, CustomEvalCallbackParallel
from utils.env_wrappers import StateCoarse, BufferWrapper, EnvCoarseWrapper, StateCoarseMultiGrid
from typing import Callable
from utils.plot_functions import plot_learning
from utils.multigrid_framework_functions import env_wrappers_multigrid, make_env, generate_beta_environement, parallalize_env, multigrid_framework

from model.ressim import Grid
from ressim_env import ResSimEnv_v0, ResSimEnv_v1
# Out:
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ad181/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
seed=1
case='case_1_multigrid_fixed'
data_dir='./data'
log_dir='./data/'+case

# %%
os.makedirs(data_dir, exist_ok=True)
os.makedirs(log_dir, exist_ok=True)

# %%
with open('../envs_params/env_data/env_train.pkl', 'rb') as input:
    env_train = pickle.load(input)

# %% [markdown]
# # define RL model and callbacks

# %%
def generate_model(env_train, seed):
    dummy_env =  generate_beta_environement(env_train, 0.5, env_train.p_x, env_train.p_y, seed)
    dummy_env_parallel = parallalize_env(dummy_env, num_actor=64, seed=seed)
    model = PPO(policy=MlpPolicy,
                env=dummy_env_parallel,
                learning_rate = 3e-6,
                n_steps = 40,
                batch_size = 16,
                n_epochs = 20,
                gamma = 0.99,
                gae_lambda = 0.95,
                clip_range = 0.1,
                clip_range_vf = None,
                ent_coef = 0.001,
                vf_coef = 0.5,
                max_grad_norm = 0.5,
                use_sde= False,
                create_eval_env= False,
                policy_kwargs = dict(net_arch=[150,100,80], log_std_init=-2.9),
                verbose = 1,
                target_kl = 0.05,
                seed = seed,
                device = "auto")
    return model

def generate_callback(env_train, best_model_save_path, log_path, eval_freq):
    dummy_env = generate_beta_environement(env_train, 0.5, env_train.p_x, env_train.p_y, seed)
    callback = CustomEvalCallbackParallel(dummy_env, 
                                          best_model_save_path=best_model_save_path, 
                                          n_eval_episodes=1,
                                          log_path=log_path, 
                                          eval_freq=eval_freq)
    return callback

# %% [markdown]
# # multigrid framework

# %%
for seed in range(1,4):
    model = multigrid_framework(env_train, 
                                generate_model,
                                generate_callback, 
                                delta_pcent=0.2, 
                                n=np.inf,
                                grid_fidelity_factor_array =[0.25, 0.5, 1.0],
                                episode_limit_array=[25000, 25000, 25000], 
                                log_dir=log_dir,
                                seed=seed)
# Out:
# Using cuda device
# seed 1: grid fidelity factor 0.25 learning ..
# environement grid size (nx x ny ): 15 x 15
# /data/ad181/RemoteDir/ada_multigrid_ppo/utils/custom_eval_callback.py:291: UserWarning: Training and eval env are not of the same type<stable_baselines3.common.vec_env.subproc_vec_env.SubprocVecEnv object at 0x7f1c7fe5c0f0> != <stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv object at 0x7f1c783f4c50>
#   warnings.warn("Training and eval env are not of the same type" f"{self.training_env} != {self.eval_env}")
# Eval num_timesteps=2560, episode_reward=0.59 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 5        |
# |    mean_reward     | 0.594    |
# | time/              |          |
# |    fps             | 205      |
# |    iterations      | 1        |
# |    time_elapsed    | 12       |
# |    total_timesteps | 2560     |
# ---------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 512
#
# Eval num_timesteps=2560, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.597       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.015503439 |
# |    clip_fraction        | 0.327       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | -0.236      |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.113       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0233     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0926      |
# -----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 1024
#
# Eval num_timesteps=2560, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.598       |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.027701218 |
# |    clip_fraction        | 0.369       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | -1.25       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.104       |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.055       |
# |    value_loss           | 0.042       |
# -----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 1536
#
# Eval num_timesteps=2560, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.601       |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.031514592 |
# |    clip_fraction        | 0.36        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | -0.308      |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0617      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0226     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0244      |
# -----------------------------------------
# policy iteration runtime: 32 seconds
#
# Total episode rollouts: 2048
#
# Eval num_timesteps=2560, episode_reward=0.60 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.603       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.023104707 |
# |    clip_fraction        | 0.353       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.25        |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0738      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0155      |
# -----------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 2560
#
# Eval num_timesteps=2560, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.608       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.019485613 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.054       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0271     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0114      |
# -----------------------------------------
# policy iteration runtime: 31 seconds
#
# Total episode rollouts: 3072
#
# Eval num_timesteps=2560, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.607       |
# | time/                   |             |
# |    fps                  | 206         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.014964166 |
# |    clip_fraction        | 0.344       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0731      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0255     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00903     |
# -----------------------------------------
# policy iteration runtime: 39 seconds
#
# Total episode rollouts: 3584
#
# Eval num_timesteps=2560, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.607       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.013802725 |
# |    clip_fraction        | 0.352       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.715       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0432      |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0263     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00821     |
# -----------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 4096
#
# Eval num_timesteps=2560, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.61        |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009057542 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.765       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0539      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00719     |
# -----------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 4608
#
# Eval num_timesteps=2560, episode_reward=0.61 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.612        |
# | time/                   |              |
# |    fps                  | 197          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0085898815 |
# |    clip_fraction        | 0.332        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.785        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0666       |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0257      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00705      |
# ------------------------------------------
# policy iteration runtime: 39 seconds
#
# Total episode rollouts: 5120
#
# Eval num_timesteps=2560, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.616       |
# | time/                   |             |
# |    fps                  | 203         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008374304 |
# |    clip_fraction        | 0.336       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0933      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00659     |
# -----------------------------------------
# policy iteration runtime: 36 seconds
#
# Total episode rollouts: 5632
#
# Eval num_timesteps=2560, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.616       |
# | time/                   |             |
# |    fps                  | 208         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009079692 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.803       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.054       |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0256     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0066      |
# -----------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 6144
#
# Eval num_timesteps=2560, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.62        |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.006509802 |
# |    clip_fraction        | 0.334       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.818       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0935      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0061      |
# -----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 6656
#
# Eval num_timesteps=2560, episode_reward=0.62 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 5          |
# |    mean_reward          | 0.625      |
# | time/                   |            |
# |    fps                  | 201        |
# |    iterations           | 1          |
# |    time_elapsed         | 12         |
# |    total_timesteps      | 2560       |
# | train/                  |            |
# |    approx_kl            | 0.00418106 |
# |    clip_fraction        | 0.345      |
# |    clip_range           | 0.1        |
# |    entropy_loss         | 91.8       |
# |    explained_variance   | 0.827      |
# |    learning_rate        | 3e-06      |
# |    loss                 | 0.0476     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0268    |
# |    std                  | 0.055      |
# |    value_loss           | 0.0059     |
# ----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 7168
#
# Eval num_timesteps=2560, episode_reward=0.63 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.63         |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0052208244 |
# |    clip_fraction        | 0.343        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.813        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0476       |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.027       |
# |    std                  | 0.055        |
# |    value_loss           | 0.00582      |
# ------------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 7680
#
# Eval num_timesteps=2560, episode_reward=0.63 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.633        |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0064288797 |
# |    clip_fraction        | 0.344        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.836        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0592       |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0258      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00552      |
# ------------------------------------------
# policy iteration runtime: 45 seconds
#
# Total episode rollouts: 8192
#
# Eval num_timesteps=2560, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.638       |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008620702 |
# |    clip_fraction        | 0.321       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0793      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00538     |
# -----------------------------------------
# policy iteration runtime: 44 seconds
#
# Total episode rollouts: 8704
#
# Eval num_timesteps=2560, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 5         |
# |    mean_reward          | 0.64      |
# | time/                   |           |
# |    fps                  | 201       |
# |    iterations           | 1         |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 2560      |
# | train/                  |           |
# |    approx_kl            | 0.0090579 |
# |    clip_fraction        | 0.346     |
# |    clip_range           | 0.1       |
# |    entropy_loss         | 91.8      |
# |    explained_variance   | 0.85      |
# |    learning_rate        | 3e-06     |
# |    loss                 | 0.0343    |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -0.0259   |
# |    std                  | 0.055     |
# |    value_loss           | 0.00513   |
# ---------------------------------------
# policy iteration runtime: 46 seconds
#
# Total episode rollouts: 9216
#
# Eval num_timesteps=2560, episode_reward=0.64 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.644       |
# | time/                   |             |
# |    fps                  | 200         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008290326 |
# |    clip_fraction        | 0.341       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.846       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0579      |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00497     |
# -----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 9728
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.647        |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0046060113 |
# |    clip_fraction        | 0.342        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0436       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0273      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00499      |
# ------------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 10240
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.647        |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0055030016 |
# |    clip_fraction        | 0.344        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.849        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0543       |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0269      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00489      |
# ------------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 10752
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.65        |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005051182 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0449      |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0278     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00464     |
# -----------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 11264
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.652        |
# | time/                   |              |
# |    fps                  | 196          |
# |    iterations           | 1            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0068758903 |
# |    clip_fraction        | 0.337        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.854        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0557       |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0253      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00485      |
# ------------------------------------------
# policy iteration runtime: 40 seconds
#
# Total episode rollouts: 11776
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.654        |
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0075951964 |
# |    clip_fraction        | 0.313        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.863        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0446       |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0242      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00449      |
# ------------------------------------------
# policy iteration runtime: 41 seconds
#
# Total episode rollouts: 12288
#
# Eval num_timesteps=2560, episode_reward=0.65 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.655        |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0058386563 |
# |    clip_fraction        | 0.336        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.866        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0622       |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0264      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00436      |
# ------------------------------------------
# policy iteration runtime: 43 seconds
#
# Total episode rollouts: 12800
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.655        |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0031508475 |
# |    clip_fraction        | 0.346        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.864        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.045        |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0268      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00456      |
# ------------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 13312
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.656       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005207449 |
# |    clip_fraction        | 0.349       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0442      |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00456     |
# -----------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 13824
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.656        |
# | time/                   |              |
# |    fps                  | 204          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0047275336 |
# |    clip_fraction        | 0.349        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.872        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0629       |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.0278      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.0042       |
# ------------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 14336
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.658        |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0057490766 |
# |    clip_fraction        | 0.348        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0488       |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.0272      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00407      |
# ------------------------------------------
# policy iteration runtime: 36 seconds
#
# Total episode rollouts: 14848
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.659        |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0070586293 |
# |    clip_fraction        | 0.335        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.877        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0631       |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.0261      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00409      |
# ------------------------------------------
# policy iteration runtime: 40 seconds
#
# Total episode rollouts: 15360
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.661       |
# | time/                   |             |
# |    fps                  | 204         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008780922 |
# |    clip_fraction        | 0.34        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.883       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0345      |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00393     |
# -----------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 15872
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.661        |
# | time/                   |              |
# |    fps                  | 207          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0075473846 |
# |    clip_fraction        | 0.351        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.879        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.075        |
# |    n_updates            | 620          |
# |    policy_gradient_loss | -0.0269      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00392      |
# ------------------------------------------
# policy iteration runtime: 33 seconds
#
# Total episode rollouts: 16384
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.661       |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007880488 |
# |    clip_fraction        | 0.35        |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0752      |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# policy iteration runtime: 34 seconds
#
# Total episode rollouts: 16896
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.66         |
# | time/                   |              |
# |    fps                  | 202          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0052749394 |
# |    clip_fraction        | 0.347        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.884        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0375       |
# |    n_updates            | 660          |
# |    policy_gradient_loss | -0.0278      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00385      |
# ------------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 17408
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.663       |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008127486 |
# |    clip_fraction        | 0.366       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0365      |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0289     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.004       |
# -----------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 17920
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.663       |
# | time/                   |             |
# |    fps                  | 197         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008793244 |
# |    clip_fraction        | 0.354       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0493      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0283     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00373     |
# -----------------------------------------
# policy iteration runtime: 45 seconds
#
# Total episode rollouts: 18432
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.664       |
# | time/                   |             |
# |    fps                  | 202         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005139178 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.074       |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00371     |
# -----------------------------------------
# policy iteration runtime: 47 seconds
#
# Total episode rollouts: 18944
#
# Eval num_timesteps=2560, episode_reward=0.66 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.665        |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0063645304 |
# |    clip_fraction        | 0.341        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.892        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.096        |
# |    n_updates            | 740          |
# |    policy_gradient_loss | -0.0258      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00363      |
# ------------------------------------------
# policy iteration runtime: 44 seconds
#
# Total episode rollouts: 19456
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.666       |
# | time/                   |             |
# |    fps                  | 201         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005401346 |
# |    clip_fraction        | 0.342       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0959      |
# |    n_updates            | 760         |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00376     |
# -----------------------------------------
# policy iteration runtime: 45 seconds
#
# Total episode rollouts: 19968
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.667       |
# | time/                   |             |
# |    fps                  | 205         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007596001 |
# |    clip_fraction        | 0.339       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0522      |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0269     |
# |    std                  | 0.0551      |
# |    value_loss           | 0.00372     |
# -----------------------------------------
# policy iteration runtime: 43 seconds
#
# Total episode rollouts: 20480
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.668        |
# | time/                   |              |
# |    fps                  | 203          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0013905704 |
# |    clip_fraction        | 0.368        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.887        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0776       |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.0298      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00373      |
# ------------------------------------------
# policy iteration runtime: 43 seconds
#
# Total episode rollouts: 20992
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.669        |
# | time/                   |              |
# |    fps                  | 206          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0068695517 |
# |    clip_fraction        | 0.351        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.889        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0609       |
# |    n_updates            | 820          |
# |    policy_gradient_loss | -0.0268      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00373      |
# ------------------------------------------
# policy iteration runtime: 42 seconds
#
# Total episode rollouts: 21504
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.67         |
# | time/                   |              |
# |    fps                  | 205          |
# |    iterations           | 1            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0037639558 |
# |    clip_fraction        | 0.351        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.891        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.049        |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0288      |
# |    std                  | 0.0551       |
# |    value_loss           | 0.00365      |
# ------------------------------------------
# policy iteration runtime: 43 seconds
#
# Total episode rollouts: 22016
#
# Eval num_timesteps=2560, episode_reward=0.67 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.671       |
# | time/                   |             |
# |    fps                  | 198         |
# |    iterations           | 1           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007283151 |
# ...
# | train/                  |             |
# |    approx_kl            | 0.009054443 |
# |    clip_fraction        | 0.373       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0444      |
# |    n_updates            | 2640        |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00476     |
# -----------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 68096
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.697       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 1           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008316383 |
# |    clip_fraction        | 0.376       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0513      |
# |    n_updates            | 2660        |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00501     |
# -----------------------------------------
# policy iteration runtime: 60 seconds
#
# Total episode rollouts: 68608
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.697        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 1            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0064386935 |
# |    clip_fraction        | 0.367        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.855        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0565       |
# |    n_updates            | 2680         |
# |    policy_gradient_loss | -0.0313      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00502      |
# ------------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 69120
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.697       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007543263 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0607      |
# |    n_updates            | 2700        |
# |    policy_gradient_loss | -0.0302     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00493     |
# -----------------------------------------
# policy iteration runtime: 63 seconds
#
# Total episode rollouts: 69632
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008719936 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0479      |
# |    n_updates            | 2720        |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.055       |
# |    value_loss           | 0.0046      |
# -----------------------------------------
# policy iteration runtime: 63 seconds
#
# Total episode rollouts: 70144
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.698        |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 1            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0061018853 |
# |    clip_fraction        | 0.354        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.859        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0507       |
# |    n_updates            | 2740         |
# |    policy_gradient_loss | -0.0297      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00484      |
# ------------------------------------------
# policy iteration runtime: 58 seconds
#
# Total episode rollouts: 70656
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008783522 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0522      |
# |    n_updates            | 2760        |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00466     |
# -----------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 71168
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.007945031 |
# |    clip_fraction        | 0.363       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0645      |
# |    n_updates            | 2780        |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00469     |
# -----------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 71680
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.009449283 |
# |    clip_fraction        | 0.371       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0493      |
# |    n_updates            | 2800        |
# |    policy_gradient_loss | -0.0305     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00456     |
# -----------------------------------------
# policy iteration runtime: 59 seconds
#
# Total episode rollouts: 72192
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.698        |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 1            |
# |    time_elapsed         | 30           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0058383197 |
# |    clip_fraction        | 0.358        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0456       |
# |    n_updates            | 2820         |
# |    policy_gradient_loss | -0.0294      |
# |    std                  | 0.055        |
# |    value_loss           | 0.0047       |
# ------------------------------------------
# policy iteration runtime: 59 seconds
#
# Total episode rollouts: 72704
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.008275598 |
# |    clip_fraction        | 0.368       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0622      |
# |    n_updates            | 2840        |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00446     |
# -----------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 73216
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 5            |
# |    mean_reward          | 0.698        |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 1            |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 2560         |
# | train/                  |              |
# |    approx_kl            | 0.0043359906 |
# |    clip_fraction        | 0.354        |
# |    clip_range           | 0.1          |
# |    entropy_loss         | 91.8         |
# |    explained_variance   | 0.869        |
# |    learning_rate        | 3e-06        |
# |    loss                 | 0.0506       |
# |    n_updates            | 2860         |
# |    policy_gradient_loss | -0.0298      |
# |    std                  | 0.055        |
# |    value_loss           | 0.00445      |
# ------------------------------------------
# policy iteration runtime: 62 seconds
#
# Total episode rollouts: 73728
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# New best mean reward!
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 84          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.011790007 |
# |    clip_fraction        | 0.365       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.863       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0723      |
# |    n_updates            | 2880        |
# |    policy_gradient_loss | -0.0303     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00457     |
# -----------------------------------------
# policy iteration runtime: 61 seconds
#
# Total episode rollouts: 74240
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 1           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005664155 |
# |    clip_fraction        | 0.364       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.066       |
# |    n_updates            | 2900        |
# |    policy_gradient_loss | -0.0297     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00438     |
# -----------------------------------------
# policy iteration runtime: 63 seconds
#
# Total episode rollouts: 74752
#
# Eval num_timesteps=2560, episode_reward=0.70 +/- 0.00
# Episode length: 5.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 5           |
# |    mean_reward          | 0.698       |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 1           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 2560        |
# | train/                  |             |
# |    approx_kl            | 0.005597493 |
# |    clip_fraction        | 0.383       |
# |    clip_range           | 0.1         |
# |    entropy_loss         | 91.8        |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 3e-06       |
# |    loss                 | 0.0463      |
# |    n_updates            | 2920        |
# |    policy_gradient_loss | -0.0316     |
# |    std                  | 0.055       |
# |    value_loss           | 0.00443     |
# -----------------------------------------
# policy iteration runtime: 62 seconds
#
# Total episode rollouts: 75264
# <div id='191c7294-f788-448e-befb-63cbd4f88bbc'></div>
# Using cuda device
